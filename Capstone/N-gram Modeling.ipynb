# %% [markdown]
# ## N-Grams Modeling

# %% [markdown]
# ***

# %%
import random
import pandas as pd

import nltk

from nltk.tokenize import word_tokenize
from nltk.util import pad_sequence
from nltk.util import bigrams
from nltk.util import ngrams
from nltk.util import everygrams
from nltk.lm.preprocessing import pad_both_ends
from nltk.lm.preprocessing import flatten
from nltk.lm import MLE


from nltk.lm.preprocessing import padded_everygram_pipeline

# %%
file_content = open("textfile.txt", encoding='utf-8').read()

# %%
file_content;

# %%
text = str(file_content) #Convert to string

# %%
tokens = nltk.word_tokenize(text)

# %%
tokens;

# %% [markdown]
# ### Data Statistics

# %%
sents = nltk.sent_tokenize(text)
print("The number of sentences is", len(sents)) 
#prints the number of sentences
# Out:
# The number of sentences is 1

# %%
words = nltk.word_tokenize(text)
print("The number of tokens is", len(words)) 
#prints the number of tokens
# Out:
# The number of tokens is 209451

# %%
average_tokens = round(len(words)/len(sents))
print("The average number of tokens per sentence is",
average_tokens) 
#prints the average number of tokens per sentence
# Out:
# The average number of tokens per sentence is 209451

# %%
unique_tokens = set(words)
print("The number of unique tokens are", len(unique_tokens)) 
#prints the number of unique tokens
# Out:
# The number of unique tokens are 24975

# %% [markdown]
# ### N-Grams = 1

# %%
list(ngrams(tokens,1))
# Out:
# [('given',),
#  ('heart',),
#  ('away',),
#  ('sordid',),
#  ('boon',),
#  ('start',),
#  ('side',),
#  ('sugar',),
#  ('sweet',),
#  ('asian',),
#  ('community',),
#  ('need',),
#  ('next',),
#  ('thing',),
#  ('know',),
#  ('asian',),
#  ('kid',),
#  ('following',),
#  ('around',),
#  ('know',),
#  ('shit',),
#  ('boy',),
#  ('wanted',),
#  ('inside',),
#  ('especially',),
#  ('two',),
#  ('particular',),
#  ('thought',),
#  ('wonderful',),
#  ('sickened',),
#  ('even',),
#  ('wonderful',),
#  ('reminds',),
#  ('quote',),
#  ('wwii',),
#  ('era',),
#  ('forget',),
#  ('go',),
#  ('say',),
#  ('something',),
#  ('like',),
#  ('hero',),
#  ('everyone',),
#  ('around',),
#  ('acting',),
#  ('badly',),
#  ('someone',),
#  ('humanitarian',),
#  ('award',),
#  ('nicholas',),
#  ('brain',),
#  ('run',),
#  ('excellent',),
#  ('processing',),
#  ('data',),
#  ('concrete',),
#  ('fact',),
#  ('work',),
#  ('best',),
#  ('thing',),
#  ('quantify',),
#  ('run',),
#  ('almost',),
#  ('insurmountable',),
#  ('challenge',),
#  ('trying',),
#  ('rationalize',),
#  ('existence',),
#  ('exceptional',),
#  ('infant',),
#  ('daughter',),
#  ('represents',),
#  ('without',),
#  ('sense',),
#  ('humor',),
#  ('loving',),
#  ('forced',),
#  ('radically',),
#  ('confront',),
#  ('limitation',),
#  ('speech',),
#  ('economic',),
#  ('inequality',),
#  ('reelection',),
#  ('game',),
#  ('dinner',),
#  ('taking',),
#  ('picture',),
#  ('race',),
#  ('outfit',),
#  ('sure',),
#  ('see',),
#  ('wore',),
#  ('sunday',),
#  ('wash',),
#  ('right',),
#  ('post',),
#  ('pic',),
#  ('next',),
#  ('day',),
#  ('heard',),
#  ('loud',),
#  ('clear',),
#  ('family',),
#  ('witness',),
#  ('exclusion',),
#  ('apprehensive',),
#  ('pusuited',),
#  ('grandfather',),
#  ('decided',),
#  ('escape',),
#  ('germany',),
#  ('heading',),
#  ('britain',),
#  ('must',),
#  ('never',),
#  ('happen',),
#  ('andy',),
#  ('say',),
#  ('tell',),
#  ('worry',),
#  ('party',),
#  ('europe',),
#  ('seem',),
#  ('get',),
#  ('popular',),
#  ('strong',),
#  ('humble',),
#  ('steinberg',),
#  ('belief',),
#  ('light',),
#  ('new',),
#  ('assessment',),
#  ('israeli',),
#  ('attack',),
#  ('back',),
#  ('burner',),
#  ('thanks',),
#  ('everyone',),
#  ('helped',),
#  ('made',),
#  ('art',),
#  ('domain',),
#  ('success',),
#  ('great',),
#  ('show',),
#  ('enthusiastic',),
#  ('crowd',),
#  ('everyone',),
#  ('already',),
#  ('looking',),
#  ('forward',),
#  ('october',),
#  ('show',),
#  ('domain',),
#  ('sweet',),
#  ('boy',),
#  ('dote',),
#  ('quite',),
#  ('capable',),
#  ('resisting',),
#  ('training',),
#  ('month',),
#  ('past',),
#  ('patience',),
#  ('consistency',),
#  ('called',),
#  ('win',),
#  ('day',),
#  ('end',),
#  ('might',),
#  ('decide',),
#  ('get',),
#  ('program',),
#  ('week',),
#  ('might',),
#  ('month',),
#  ('time',),
#  ('tell',),
#  ('think',),
#  ('know',),
#  ('likely',),
#  ('response',),
#  ('training',),
#  ('go',),
#  ('new',),
#  ('level',),
#  ('reason',),
#  ('initially',),
#  ('investigate',),
#  ('catalogue',),
#  ('one',),
#  ('friday',),
#  ('work',),
#  ('talking',),
#  ('another',),
#  ('friend',),
#  ('loved',),
#  ('ann',),
#  ('peebles',),
#  ('next',),
#  ('day',),
#  ('way',),
#  ('town',),
#  ('shop',),
#  ('decided',),
#  ('simply',),
#  ('buy',),
#  ('peebles',),
#  ('record',),
#  ('first',),
#  ('stop',),
#  ('reckless',),
#  ('berwick',),
#  ('st',),
#  ('still',),
#  ('basement',),
#  ('box',),
#  ('soul',),
#  ('single',),
#  ('sat',),
#  ('counter',),
#  ('inherited',),
#  ('dad',),
#  ('hoarding',),
#  ('tendency',),
#  ('acute',),
#  ('sense',),
#  ('relative',),
#  ('value',),
#  ('never',),
#  ('bought',),
#  ('many',),
#  ('must',),
#  ('trendily',),
#  ('refer',),
#  ('time',),
#  ('deliberately',),
#  ('avoid',),
#  ('looking',),
#  ('beyond',),
#  ('lp',),
#  ('section',),
#  ('shop',),
#  ('mission',),
#  ('time',),
#  ('though',),
#  ('miraculously',),
#  ('began',),
#  ('flick',),
#  ('second',),
#  ('record',),
#  ('box',),
#  ('willed',),
#  ('excitedly',),
#  ('parted',),
#  ('memory',),
#  ('anything',),
#  ('else',),
#  ('bought',),
#  ('day',),
#  ('remember',),
#  ('definitely',),
#  ('raining',),
#  ('getting',),
#  ('record',),
#  ('home',),
#  ('bonus',),
#  ('discovery',),
#  ('equally',),
#  ('brilliant',),
#  ('part',),
#  ('whose',),
#  ('intro',),
#  ('backbone',),
#  ('gza',),
#  ('track',),
#  ('bit',),
#  ('obsessed',),
#  ('time',),
#  ('huge',),
#  ('proportion',),
#  ('early',),
#  ('rza',),
#  ('production',),
#  ('relies',),
#  ('hi',),
#  ('back',),
#  ('catalogue',),
#  ('contrast',),
#  ('song',),
#  ('much',),
#  ('positive',),
#  ('title',),
#  ('indicates',),
#  ('bidding',),
#  ('goodbye',),
#  ('trouble',),
#  ('sadness',),
#  ('rather',),
#  ('customary',),
#  ('peebles',),
#  ('telling',),
#  ('piss',),
#  ('forest',),
#  ('city',),
#  ('ratner',),
#  ('company',),
#  ('brooklyn',),
#  ('event',),
#  ('center',),
#  ('subsidiary',),
#  ('would',),
#  ('tiny',),
#  ('fraction',),
#  ('job',),
#  ('would',),
#  ('hired',),
#  ('aeg',),
#  ('charge',),
#  ('arena',),
#  ('operation',),
#  ('hired',),
#  ('levy',),
#  ('restaurant',),
#  ('charge',),
#  ('food',),
#  ('service',),
#  ('exciting',),
#  ('news',),
#  ('august',),
#  ('sweet',),
#  ('baby',),
#  ('jane',),
#  ('joined',),
#  ('family',),
#  ('born',),
#  ('hour',),
#  ('labor',),
#  ('much',),
#  ('better',),
#  ('annabelle',),
#  ('hour',),
#  ('labor',),
#  ('long',),
#  ('jane',),
#  ('look',),
#  ('lot',),
#  ('like',),
#  ('annabelle',),
#  ('baby',),
#  ('definitely',),
#  ('personality',),
#  ('happy',),
#  ('sweet',),
#  ('baby',),
#  ('girl',),
#  ('could',),
#  ('join',),
#  ('family',),
#  ('annabelle',),
#  ('love',),
#  ('new',),
#  ('little',),
#  ('sister',),
#  ('jane',),
#  ('little',),
#  ('live',),
#  ('wire',),
#  ('right',),
#  ('jane',),
#  ('born',),
#  ('could',),
#  ('lift',),
#  ('head',),
#  ('always',),
#  ('moving',),
#  ('cuddly',),
#  ('baby',),
#  ('like',),
#  ('annabelle',),
#  ('still',),
#  ('sweet',),
#  ('happy',),
#  ('little',),
#  ('one',),
#  ('move',),
#  ('much',),
#  ('learned',),
#  ('roll',),
#  ('month',),
#  ('month',),
#  ('army',),
#  ('crawling',),
#  ('everywhere',),
#  ('crazy',),
#  ('huh',),
#  ('little',),
#  ('determined',),
#  ('one',),
#  ('probably',),
#  ('going',),
#  ('walk',),
#  ('soon',),
#  ('swear',),
#  ('jane',),
#  ('month',),
#  ('dr',),
#  ('appointment',),
#  ('weighed',),
#  ('lb',),
#  ('oz',),
#  ('make',),
#  ('percentile',),
#  ('little',),
#  ('one',),
#  ('probably',),
#  ('move',),
#  ('time',),
#  ('annabelle',),
#  ('good',),
#  ('big',),
#  ('sister',),
#  ('love',),
#  ('make',),
#  ('laugh',),
#  ('sad',),
#  ('give',),
#  ('toy',),
#  ('try',),
#  ('everything',),
#  ('make',),
#  ('happy',),
#  ('moment',),
#  ('hear',),
#  ('jane',),
#  ('cry',),
#  ('see',),
#  ('annabelle',),
#  ('trying',),
#  ('ride',),
#  ('back',),
#  ('like',),
#  ('daddy',),
#  ('guess',),
#  ('big',),
#  ('sister',),
#  ('get',),
#  ('kind',),
#  ('crazy',),
#  ('mom',),
#  ('two',),
#  ('love',),
#  ('always',),
#  ('adventure',),
#  ('act',),
#  ('color',),
#  ('law',),
#  ('include',),
#  ('act',),
#  ('done',),
#  ('federal',),
#  ('state',),
#  ('local',),
#  ('official',),
#  ('within',),
#  ('bound',),
#  ('limit',),
#  ('lawful',),
#  ('authority',),
#  ('also',),
#  ('act',),
#  ('done',),
#  ('without',),
#  ('beyond',),
#  ('bound',),
#  ('lawful',),
#  ('authority',),
#  ('provided',),
#  ('order',),
#  ('unlawful',),
#  ('act',),
#  ('official',),
#  ('done',),
#  ('color',),
#  ('law',),
#  ('unlawful',),
#  ('act',),
#  ('must',),
#  ('done',),
#  ('official',),
#  ('purporting',),
#  ('pretending',),
#  ('act',),
#  ('performance',),
#  ('official',),
#  ('duty',),
#  ('definition',),
#  ('includes',),
#  ('addition',),
#  ('law',),
#  ('enforcement',),
#  ('official',),
#  ('individual',),
#  ('mayor',),
#  ('council',),
#  ('person',),
#  ('judge',),
#  ('nursing',),
#  ('home',),
#  ('proprietor',),
#  ('security',),
#  ('guard',),
#  ('person',),
#  ('bound',),
#  ('law',),
#  ('statute',),
#  ('ordinance',),
#  ('custom',),
#  ('god',),
#  ('love',),
#  ('drunkard',),
#  ('cry',),
#  ('firm',),
#  ('trimtabs',),
#  ('taking',),
#  ('cautious',),
#  ('stance',),
#  ('reducing',),
#  ('market',),
#  ('exposure',),
#  ('zero',),
#  ('exposure',),
#  ('trimtabs',),
#  ('reasoning',),
#  ('end',),
#  ('spell',),
#  ('end',),
#  ('propping',),
#  ('market',),
#  ('certainly',),
#  ('understandable',),
#  ('information',),
#  ('well',),
#  ('known',),
#  ('already',),
#  ('priced',),
#  ('market',),
#  ('go',),
#  ('write',),
#  ('client',),
#  ('p',),
#  ('interim',),
#  ('closing',),
#  ('high',),
#  ('april',),
#  ('expect',),
#  ('market',),
#  ('action',),
#  ('get',),
#  ('even',),
#  ('uglier',),
#  ('terrible',),
#  ('track',),
#  ('record',),
#  ('make',),
#  ('tempting',),
#  ('fade',),
#  ('lump',),
#  ('together',),
#  ('odd',),
#  ('collection',),
#  ('beer',),
#  ('ipa',),
#  ('berliner',),
#  ('weisse',),
#  ('pilsener',),
#  ('grätzer',),
#  ('beer',),
#  ('whose',),
#  ('connection',),
#  ('pale',),
#  ('colour',),
#  ('missed',),
#  ('grätzer',),
#  ('reference',),
#  ('first',),
#  ('time',),
#  ('read',),
#  ('another',),
#  ('one',),
#  ('collection',),
#  ('first',),
#  ('mention',),
#  ('remember',),
#  ('using',),
#  ('hop',),
#  ('year',),
#  ('old',),
#  ('red',),
#  ('bell',),
#  ('pepper',),
#  ('sliced',),
#  ('kathleen',),
#  ('peacock',),
#  ('thrilling',),
#  ('novel',),
#  ('first',),
#  ('hemlock',),
#  ('trilogy',),
#  ('urban',),
#  ('fantasy',),
#  ('series',),
#  ('filled',),
#  ('provocative',),
#  ('question',),
#  ('prejudice',),
#  ('trust',),
#  ('lie',),
#  ('love',),
#  ('anyway',),
#  ('brought',),
#  ('biscoff',),
#  ('spread',),
#  ('home',),
#  ('waited',),
#  ('approximately',),
#  ('second',),
#  ('grabbing',),
#  ('spoon',),
#  ('giving',),
#  ('taste',),
#  ('verdict',),
#  ('taste',),
#  ('like',),
#  ('cooky',),
#  ('good',),
#  ('better',),
#  ('nutella',),
#  ('good',),
#  ('unfortunately',),
#  ('men',),
#  ('reached',),
#  ('second',),
#  ('floor',),
#  ('could',),
#  ('find',),
#  ('gun',),
#  ('climbed',),
#  ('roof',),
#  ('escape',),
#  ('outside',),
#  ('grandfather',),
#  ('yard',),
#  ('saw',),
#  ('dad',),
#  ('yard',),
#  ('work',),
#  ('saw',),
#  ('fictional',),
#  ('dog',),
#  ('somehow',),
#  ('knew',),
#  ('yelled',),
#  ('dad',),
#  ('get',),
#  ('grandfather',),
#  ('truck',),
#  ('men',),
#  ('gun',),
#  ('trying',),
#  ('kill',),
#  ('wrist',),
#  ('bind',),
#  ('successful',),
#  ('attack',),
#  ('whipwhirl',),
#  ('bind',),
#  ('opponent',),
#  ('wrist',),
#  ('possibility',),
#  ('victim',),
#  ('fumble',),
#  ('drop',),
#  ('anything',),
#  ('might',),
#  ('holding',),
#  ('hand',),
#  ('base',),
#  ('chance',),
#  ('fumble',),
#  ('whipwhirl',),
#  ('wrist',),
#  ('attack',),
#  ('minus',),
#  ('per',),
#  ('point',),
#  ('dexterity',),
#  ('affected',),
#  ('target',),
#  ('character',),
#  ('dexterity',),
#  ('would',),
#  ('chance',),
#  ('fumbling',),
#  ('type',),
#  ('attack',),
#  ('chris',),
#  ('bye',),
#  ('bye',),
#  ('try',),
#  ('best',),
#  ('never',),
#  ('forget',),
#  ('please',),
#  ('remember',),
#  ('name',),
#  ('tell',),
#  ('lol',),
#  ('make',),
#  ('priority',),
#  ('day',),
#  ('read',),
#  ('gratitude',),
#  ('list',),
#  ('waking',),
#  ('going',),
#  ('bed',),
#  ('least',),
#  ('one',),
#  ('time',),
#  ('day',),
#  ('know',),
#  ('whether',),
#  ('post',),
#  ('significance',),
#  ('know',),
#  ('blessing',),
#  ('bountiful',),
#  ('oz',),
#  ('light',),
#  ('sour',),
#  ('cream',),
#  ('video',),
#  ('talk',),
#  ('tip',),
#  ('give',),
#  ('tour',),
#  ('system',),
#  ('tried',),
#  ('write',),
#  ('clearly',),
#  ('could',),
#  ('post',),
#  ('sometimes',),
#  ('better',),
#  ('see',),
#  ('action',),
#  ('tough',),
#  ('explain',),
#  ('jf',),
#  ('lot',),
#  ('guideline',),
#  ('lot',),
#  ('people',),
#  ('treat',),
#  ('immutable',),
#  ('law',),
#  ('like',),
#  ('tell',),
#  ('use',),
#  ('lot',),
#  ('distraction',),
#  ('like',),
#  ('pt',),
#  ('time',),
#  ('roman',),
#  ('never',),
#  ('submitted',),
#  ('m',),
#  ('time',),
#  ('roman',),
#  ('never',),
#  ('one',),
#  ('rejected',),
#  ('wrong',),
#  ('font',),
#  ('tell',),
#  ('adrian',),
#  ('write',),
#  ('might',),
#  ('think',),
#  ('prescription',),
#  ('successful',),
#  ('writing',),
#  ('possibly',),
#  ('bad',),
#  ('way',),
#  ('write',),
#  ('people',),
#  ('work',),
#  ('way',),
#  ('writing',),
#  ('work',),
#  ('much',),
#  ('activity',),
#  ('writing',),
#  ('going',),
#  ('say',),
#  ('detailed',),
#  ('plan',),
#  ('write',),
#  ('detailed',),
#  ('plan',),
#  ('want',),
#  ('get',),
#  ('adrian',),
#  ('talk',),
#  ('novel',),
#  ('understand',),
#  ('writing',),
#  ('work',),
#  ('could',),
#  ('work',),
#  ('ask',),
#  ('question',),
#  ('like',),
#  ('narrator',),
#  ('omniscient',),
#  ('narrator',),
#  ('narrator',),
#  ('character',),
#  ('reliable',),
#  ('switch',),
#  ('point',),
#  ('view',),
#  ('main',),
#  ('character',),
#  ('flaw',),
#  ('opinion',),
#  ('share',),
#  ('change',),
#  ('course',),
#  ('book',),
#  ('medium',),
#  ('saucepan',),
#  ('combine',),
#  ('butter',),
#  ('salt',),
#  ('water',),
#  ('mexican',),
#  ('chocolate',),
#  ('grated',),
#  ('chop',),
#  ('prefer',),
#  ('medium',),
#  ('high',),
#  ('heat',),
#  ('bring',),
#  ('mixture',),
#  ('low',),
#  ('boil',),
#  ('sure',),
#  ('wondered',),
#  ('got',),
#  ('western',),
#  ('writing',),
#  ('grew',),
#  ('watching',),
#  ('gunsmoke',),
#  ('paladin',),
#  ('bonanza',),
#  ('etc',),
#  ('dad',),
#  ('loved',),
#  ('western',),
#  ('top',),
#  ('fact',),
#  ('enjoy',),
#  ('reading',),
#  ('history',),
#  ('mind',),
#  ('read',),
#  ('history',),
#  ('textbook',),
#  ('school',),
#  ('fact',),
#  ('may',),
#  ('kid',),
#  ('read',),
#  ('whole',),
#  ('book',),
#  ('math',),
#  ('get',),
#  ('wrong',),
#  ('actually',),
#  ('mind',),
#  ('folding',),
#  ('laundry',),
#  ('really',),
#  ('hate',),
#  ('putting',),
#  ('away',),
#  ('digress',),
#  ('well',),
#  ('play',),
#  ('dungeon',),
#  ('dragon',),
#  ('asking',),
#  ('buy',),
#  ('shirt',),
#  ('today',),
#  ('iraq',),
#  ('mosul',),
#  ('imam',),
#  ('gunned',),
#  ('outside',),
#  ('mosque',),
#  ('religion',),
#  ('peace',),
#  ('rival',),
#  ('another',),
#  ('cool',),
#  ('discovery',),
#  ('traif',),
#  ('bike',),
#  ('geshefton',),
#  ('williamburg',),
#  ('side',),
#  ('bridge',),
#  ('address',),
#  ('south',),
#  ('street',),
#  ('bedford',),
#  ('berry',),
#  ('street',),
#  ('please',),
#  ('note',),
#  ('open',),
#  ('accept',),
#  ('cash',),
#  ('form',),
#  ('payment',),
#  ('happen',),
#  ('get',),
#  ('flat',),
#  ('pump',),
#  ('use',),
#  ('also',),
#  ('outside',),
#  ('vending',),
#  ('machine',),
#  ('buy',),
#  ('pump',),
#  ('tire',),
#  ('repair',),
#  ('kit',),
#  ('small',),
#  ('etc',),
#  ('although',),
#  ('longer',),
#  ('rent',),
#  ('bike',),
#  ('catch',),
#  ('flat',),
#  ('place',),
#  ('go',),
#  ('repair',),
#  ('direction',),
#  ('traif',),
#  ('bike',),
#  ('gesheft',),
#  ('located',),
#  ('south',),
#  ('street',),
#  ('click',),
#  ('link',),
#  ('public',),
#  ('employee',),
#  ('father',),
#  ('top',),
#  ('busy',),
#  ('enjoying',),
#  ('mother',),
#  ('realized',),
#  ('another',),
#  ('presence',),
#  ('kind',),
#  ('dad',),
#  ('altho',),
#  ('pure',),
#  ('energy',),
#  ('physical',),
#  ('recognized',),
#  ('energy',),
#  ('signature',),
#  ('right',),
#  ('franklyn',),
#  ('pleiadian',),
#  ('guide',),
#  ...]

# %% [markdown]
# ### N-Grams = 2

# %%
list(ngrams(tokens,2))
# Out:
# [('given', 'heart'),
#  ('heart', 'away'),
#  ('away', 'sordid'),
#  ('sordid', 'boon'),
#  ('boon', 'start'),
#  ('start', 'side'),
#  ('side', 'sugar'),
#  ('sugar', 'sweet'),
#  ('sweet', 'asian'),
#  ('asian', 'community'),
#  ('community', 'need'),
#  ('need', 'next'),
#  ('next', 'thing'),
#  ('thing', 'know'),
#  ('know', 'asian'),
#  ('asian', 'kid'),
#  ('kid', 'following'),
#  ('following', 'around'),
#  ('around', 'know'),
#  ('know', 'shit'),
#  ('shit', 'boy'),
#  ('boy', 'wanted'),
#  ('wanted', 'inside'),
#  ('inside', 'especially'),
#  ('especially', 'two'),
#  ('two', 'particular'),
#  ('particular', 'thought'),
#  ('thought', 'wonderful'),
#  ('wonderful', 'sickened'),
#  ('sickened', 'even'),
#  ('even', 'wonderful'),
#  ('wonderful', 'reminds'),
#  ('reminds', 'quote'),
#  ('quote', 'wwii'),
#  ('wwii', 'era'),
#  ('era', 'forget'),
#  ('forget', 'go'),
#  ('go', 'say'),
#  ('say', 'something'),
#  ('something', 'like'),
#  ('like', 'hero'),
#  ('hero', 'everyone'),
#  ('everyone', 'around'),
#  ('around', 'acting'),
#  ('acting', 'badly'),
#  ('badly', 'someone'),
#  ('someone', 'humanitarian'),
#  ('humanitarian', 'award'),
#  ('award', 'nicholas'),
#  ('nicholas', 'brain'),
#  ('brain', 'run'),
#  ('run', 'excellent'),
#  ('excellent', 'processing'),
#  ('processing', 'data'),
#  ('data', 'concrete'),
#  ('concrete', 'fact'),
#  ('fact', 'work'),
#  ('work', 'best'),
#  ('best', 'thing'),
#  ('thing', 'quantify'),
#  ('quantify', 'run'),
#  ('run', 'almost'),
#  ('almost', 'insurmountable'),
#  ('insurmountable', 'challenge'),
#  ('challenge', 'trying'),
#  ('trying', 'rationalize'),
#  ('rationalize', 'existence'),
#  ('existence', 'exceptional'),
#  ('exceptional', 'infant'),
#  ('infant', 'daughter'),
#  ('daughter', 'represents'),
#  ('represents', 'without'),
#  ('without', 'sense'),
#  ('sense', 'humor'),
#  ('humor', 'loving'),
#  ('loving', 'forced'),
#  ('forced', 'radically'),
#  ('radically', 'confront'),
#  ('confront', 'limitation'),
#  ('limitation', 'speech'),
#  ('speech', 'economic'),
#  ('economic', 'inequality'),
#  ('inequality', 'reelection'),
#  ('reelection', 'game'),
#  ('game', 'dinner'),
#  ('dinner', 'taking'),
#  ('taking', 'picture'),
#  ('picture', 'race'),
#  ('race', 'outfit'),
#  ('outfit', 'sure'),
#  ('sure', 'see'),
#  ('see', 'wore'),
#  ('wore', 'sunday'),
#  ('sunday', 'wash'),
#  ('wash', 'right'),
#  ('right', 'post'),
#  ('post', 'pic'),
#  ('pic', 'next'),
#  ('next', 'day'),
#  ('day', 'heard'),
#  ('heard', 'loud'),
#  ('loud', 'clear'),
#  ('clear', 'family'),
#  ('family', 'witness'),
#  ('witness', 'exclusion'),
#  ('exclusion', 'apprehensive'),
#  ('apprehensive', 'pusuited'),
#  ('pusuited', 'grandfather'),
#  ('grandfather', 'decided'),
#  ('decided', 'escape'),
#  ('escape', 'germany'),
#  ('germany', 'heading'),
#  ('heading', 'britain'),
#  ('britain', 'must'),
#  ('must', 'never'),
#  ('never', 'happen'),
#  ('happen', 'andy'),
#  ('andy', 'say'),
#  ('say', 'tell'),
#  ('tell', 'worry'),
#  ('worry', 'party'),
#  ('party', 'europe'),
#  ('europe', 'seem'),
#  ('seem', 'get'),
#  ('get', 'popular'),
#  ('popular', 'strong'),
#  ('strong', 'humble'),
#  ('humble', 'steinberg'),
#  ('steinberg', 'belief'),
#  ('belief', 'light'),
#  ('light', 'new'),
#  ('new', 'assessment'),
#  ('assessment', 'israeli'),
#  ('israeli', 'attack'),
#  ('attack', 'back'),
#  ('back', 'burner'),
#  ('burner', 'thanks'),
#  ('thanks', 'everyone'),
#  ('everyone', 'helped'),
#  ('helped', 'made'),
#  ('made', 'art'),
#  ('art', 'domain'),
#  ('domain', 'success'),
#  ('success', 'great'),
#  ('great', 'show'),
#  ('show', 'enthusiastic'),
#  ('enthusiastic', 'crowd'),
#  ('crowd', 'everyone'),
#  ('everyone', 'already'),
#  ('already', 'looking'),
#  ('looking', 'forward'),
#  ('forward', 'october'),
#  ('october', 'show'),
#  ('show', 'domain'),
#  ('domain', 'sweet'),
#  ('sweet', 'boy'),
#  ('boy', 'dote'),
#  ('dote', 'quite'),
#  ('quite', 'capable'),
#  ('capable', 'resisting'),
#  ('resisting', 'training'),
#  ('training', 'month'),
#  ('month', 'past'),
#  ('past', 'patience'),
#  ('patience', 'consistency'),
#  ('consistency', 'called'),
#  ('called', 'win'),
#  ('win', 'day'),
#  ('day', 'end'),
#  ('end', 'might'),
#  ('might', 'decide'),
#  ('decide', 'get'),
#  ('get', 'program'),
#  ('program', 'week'),
#  ('week', 'might'),
#  ('might', 'month'),
#  ('month', 'time'),
#  ('time', 'tell'),
#  ('tell', 'think'),
#  ('think', 'know'),
#  ('know', 'likely'),
#  ('likely', 'response'),
#  ('response', 'training'),
#  ('training', 'go'),
#  ('go', 'new'),
#  ('new', 'level'),
#  ('level', 'reason'),
#  ('reason', 'initially'),
#  ('initially', 'investigate'),
#  ('investigate', 'catalogue'),
#  ('catalogue', 'one'),
#  ('one', 'friday'),
#  ('friday', 'work'),
#  ('work', 'talking'),
#  ('talking', 'another'),
#  ('another', 'friend'),
#  ('friend', 'loved'),
#  ('loved', 'ann'),
#  ('ann', 'peebles'),
#  ('peebles', 'next'),
#  ('next', 'day'),
#  ('day', 'way'),
#  ('way', 'town'),
#  ('town', 'shop'),
#  ('shop', 'decided'),
#  ('decided', 'simply'),
#  ('simply', 'buy'),
#  ('buy', 'peebles'),
#  ('peebles', 'record'),
#  ('record', 'first'),
#  ('first', 'stop'),
#  ('stop', 'reckless'),
#  ('reckless', 'berwick'),
#  ('berwick', 'st'),
#  ('st', 'still'),
#  ('still', 'basement'),
#  ('basement', 'box'),
#  ('box', 'soul'),
#  ('soul', 'single'),
#  ('single', 'sat'),
#  ('sat', 'counter'),
#  ('counter', 'inherited'),
#  ('inherited', 'dad'),
#  ('dad', 'hoarding'),
#  ('hoarding', 'tendency'),
#  ('tendency', 'acute'),
#  ('acute', 'sense'),
#  ('sense', 'relative'),
#  ('relative', 'value'),
#  ('value', 'never'),
#  ('never', 'bought'),
#  ('bought', 'many'),
#  ('many', 'must'),
#  ('must', 'trendily'),
#  ('trendily', 'refer'),
#  ('refer', 'time'),
#  ('time', 'deliberately'),
#  ('deliberately', 'avoid'),
#  ('avoid', 'looking'),
#  ('looking', 'beyond'),
#  ('beyond', 'lp'),
#  ('lp', 'section'),
#  ('section', 'shop'),
#  ('shop', 'mission'),
#  ('mission', 'time'),
#  ('time', 'though'),
#  ('though', 'miraculously'),
#  ('miraculously', 'began'),
#  ('began', 'flick'),
#  ('flick', 'second'),
#  ('second', 'record'),
#  ('record', 'box'),
#  ('box', 'willed'),
#  ('willed', 'excitedly'),
#  ('excitedly', 'parted'),
#  ('parted', 'memory'),
#  ('memory', 'anything'),
#  ('anything', 'else'),
#  ('else', 'bought'),
#  ('bought', 'day'),
#  ('day', 'remember'),
#  ('remember', 'definitely'),
#  ('definitely', 'raining'),
#  ('raining', 'getting'),
#  ('getting', 'record'),
#  ('record', 'home'),
#  ('home', 'bonus'),
#  ('bonus', 'discovery'),
#  ('discovery', 'equally'),
#  ('equally', 'brilliant'),
#  ('brilliant', 'part'),
#  ('part', 'whose'),
#  ('whose', 'intro'),
#  ('intro', 'backbone'),
#  ('backbone', 'gza'),
#  ('gza', 'track'),
#  ('track', 'bit'),
#  ('bit', 'obsessed'),
#  ('obsessed', 'time'),
#  ('time', 'huge'),
#  ('huge', 'proportion'),
#  ('proportion', 'early'),
#  ('early', 'rza'),
#  ('rza', 'production'),
#  ('production', 'relies'),
#  ('relies', 'hi'),
#  ('hi', 'back'),
#  ('back', 'catalogue'),
#  ('catalogue', 'contrast'),
#  ('contrast', 'song'),
#  ('song', 'much'),
#  ('much', 'positive'),
#  ('positive', 'title'),
#  ('title', 'indicates'),
#  ('indicates', 'bidding'),
#  ('bidding', 'goodbye'),
#  ('goodbye', 'trouble'),
#  ('trouble', 'sadness'),
#  ('sadness', 'rather'),
#  ('rather', 'customary'),
#  ('customary', 'peebles'),
#  ('peebles', 'telling'),
#  ('telling', 'piss'),
#  ('piss', 'forest'),
#  ('forest', 'city'),
#  ('city', 'ratner'),
#  ('ratner', 'company'),
#  ('company', 'brooklyn'),
#  ('brooklyn', 'event'),
#  ('event', 'center'),
#  ('center', 'subsidiary'),
#  ('subsidiary', 'would'),
#  ('would', 'tiny'),
#  ('tiny', 'fraction'),
#  ('fraction', 'job'),
#  ('job', 'would'),
#  ('would', 'hired'),
#  ('hired', 'aeg'),
#  ('aeg', 'charge'),
#  ('charge', 'arena'),
#  ('arena', 'operation'),
#  ('operation', 'hired'),
#  ('hired', 'levy'),
#  ('levy', 'restaurant'),
#  ('restaurant', 'charge'),
#  ('charge', 'food'),
#  ('food', 'service'),
#  ('service', 'exciting'),
#  ('exciting', 'news'),
#  ('news', 'august'),
#  ('august', 'sweet'),
#  ('sweet', 'baby'),
#  ('baby', 'jane'),
#  ('jane', 'joined'),
#  ('joined', 'family'),
#  ('family', 'born'),
#  ('born', 'hour'),
#  ('hour', 'labor'),
#  ('labor', 'much'),
#  ('much', 'better'),
#  ('better', 'annabelle'),
#  ('annabelle', 'hour'),
#  ('hour', 'labor'),
#  ('labor', 'long'),
#  ('long', 'jane'),
#  ('jane', 'look'),
#  ('look', 'lot'),
#  ('lot', 'like'),
#  ('like', 'annabelle'),
#  ('annabelle', 'baby'),
#  ('baby', 'definitely'),
#  ('definitely', 'personality'),
#  ('personality', 'happy'),
#  ('happy', 'sweet'),
#  ('sweet', 'baby'),
#  ('baby', 'girl'),
#  ('girl', 'could'),
#  ('could', 'join'),
#  ('join', 'family'),
#  ('family', 'annabelle'),
#  ('annabelle', 'love'),
#  ('love', 'new'),
#  ('new', 'little'),
#  ('little', 'sister'),
#  ('sister', 'jane'),
#  ('jane', 'little'),
#  ('little', 'live'),
#  ('live', 'wire'),
#  ('wire', 'right'),
#  ('right', 'jane'),
#  ('jane', 'born'),
#  ('born', 'could'),
#  ('could', 'lift'),
#  ('lift', 'head'),
#  ('head', 'always'),
#  ('always', 'moving'),
#  ('moving', 'cuddly'),
#  ('cuddly', 'baby'),
#  ('baby', 'like'),
#  ('like', 'annabelle'),
#  ('annabelle', 'still'),
#  ('still', 'sweet'),
#  ('sweet', 'happy'),
#  ('happy', 'little'),
#  ('little', 'one'),
#  ('one', 'move'),
#  ('move', 'much'),
#  ('much', 'learned'),
#  ('learned', 'roll'),
#  ('roll', 'month'),
#  ('month', 'month'),
#  ('month', 'army'),
#  ('army', 'crawling'),
#  ('crawling', 'everywhere'),
#  ('everywhere', 'crazy'),
#  ('crazy', 'huh'),
#  ('huh', 'little'),
#  ('little', 'determined'),
#  ('determined', 'one'),
#  ('one', 'probably'),
#  ('probably', 'going'),
#  ('going', 'walk'),
#  ('walk', 'soon'),
#  ('soon', 'swear'),
#  ('swear', 'jane'),
#  ('jane', 'month'),
#  ('month', 'dr'),
#  ('dr', 'appointment'),
#  ('appointment', 'weighed'),
#  ('weighed', 'lb'),
#  ('lb', 'oz'),
#  ('oz', 'make'),
#  ('make', 'percentile'),
#  ('percentile', 'little'),
#  ('little', 'one'),
#  ('one', 'probably'),
#  ('probably', 'move'),
#  ('move', 'time'),
#  ('time', 'annabelle'),
#  ('annabelle', 'good'),
#  ('good', 'big'),
#  ('big', 'sister'),
#  ('sister', 'love'),
#  ('love', 'make'),
#  ('make', 'laugh'),
#  ('laugh', 'sad'),
#  ('sad', 'give'),
#  ('give', 'toy'),
#  ('toy', 'try'),
#  ('try', 'everything'),
#  ('everything', 'make'),
#  ('make', 'happy'),
#  ('happy', 'moment'),
#  ('moment', 'hear'),
#  ('hear', 'jane'),
#  ('jane', 'cry'),
#  ('cry', 'see'),
#  ('see', 'annabelle'),
#  ('annabelle', 'trying'),
#  ('trying', 'ride'),
#  ('ride', 'back'),
#  ('back', 'like'),
#  ('like', 'daddy'),
#  ('daddy', 'guess'),
#  ('guess', 'big'),
#  ('big', 'sister'),
#  ('sister', 'get'),
#  ('get', 'kind'),
#  ('kind', 'crazy'),
#  ('crazy', 'mom'),
#  ('mom', 'two'),
#  ('two', 'love'),
#  ('love', 'always'),
#  ('always', 'adventure'),
#  ('adventure', 'act'),
#  ('act', 'color'),
#  ('color', 'law'),
#  ('law', 'include'),
#  ('include', 'act'),
#  ('act', 'done'),
#  ('done', 'federal'),
#  ('federal', 'state'),
#  ('state', 'local'),
#  ('local', 'official'),
#  ('official', 'within'),
#  ('within', 'bound'),
#  ('bound', 'limit'),
#  ('limit', 'lawful'),
#  ('lawful', 'authority'),
#  ('authority', 'also'),
#  ('also', 'act'),
#  ('act', 'done'),
#  ('done', 'without'),
#  ('without', 'beyond'),
#  ('beyond', 'bound'),
#  ('bound', 'lawful'),
#  ('lawful', 'authority'),
#  ('authority', 'provided'),
#  ('provided', 'order'),
#  ('order', 'unlawful'),
#  ('unlawful', 'act'),
#  ('act', 'official'),
#  ('official', 'done'),
#  ('done', 'color'),
#  ('color', 'law'),
#  ('law', 'unlawful'),
#  ('unlawful', 'act'),
#  ('act', 'must'),
#  ('must', 'done'),
#  ('done', 'official'),
#  ('official', 'purporting'),
#  ('purporting', 'pretending'),
#  ('pretending', 'act'),
#  ('act', 'performance'),
#  ('performance', 'official'),
#  ('official', 'duty'),
#  ('duty', 'definition'),
#  ('definition', 'includes'),
#  ('includes', 'addition'),
#  ('addition', 'law'),
#  ('law', 'enforcement'),
#  ('enforcement', 'official'),
#  ('official', 'individual'),
#  ('individual', 'mayor'),
#  ('mayor', 'council'),
#  ('council', 'person'),
#  ('person', 'judge'),
#  ('judge', 'nursing'),
#  ('nursing', 'home'),
#  ('home', 'proprietor'),
#  ('proprietor', 'security'),
#  ('security', 'guard'),
#  ('guard', 'person'),
#  ('person', 'bound'),
#  ('bound', 'law'),
#  ('law', 'statute'),
#  ('statute', 'ordinance'),
#  ('ordinance', 'custom'),
#  ('custom', 'god'),
#  ('god', 'love'),
#  ('love', 'drunkard'),
#  ('drunkard', 'cry'),
#  ('cry', 'firm'),
#  ('firm', 'trimtabs'),
#  ('trimtabs', 'taking'),
#  ('taking', 'cautious'),
#  ('cautious', 'stance'),
#  ('stance', 'reducing'),
#  ('reducing', 'market'),
#  ('market', 'exposure'),
#  ('exposure', 'zero'),
#  ('zero', 'exposure'),
#  ('exposure', 'trimtabs'),
#  ('trimtabs', 'reasoning'),
#  ('reasoning', 'end'),
#  ('end', 'spell'),
#  ('spell', 'end'),
#  ('end', 'propping'),
#  ('propping', 'market'),
#  ('market', 'certainly'),
#  ('certainly', 'understandable'),
#  ('understandable', 'information'),
#  ('information', 'well'),
#  ('well', 'known'),
#  ('known', 'already'),
#  ('already', 'priced'),
#  ('priced', 'market'),
#  ('market', 'go'),
#  ('go', 'write'),
#  ('write', 'client'),
#  ('client', 'p'),
#  ('p', 'interim'),
#  ('interim', 'closing'),
#  ('closing', 'high'),
#  ('high', 'april'),
#  ('april', 'expect'),
#  ('expect', 'market'),
#  ('market', 'action'),
#  ('action', 'get'),
#  ('get', 'even'),
#  ('even', 'uglier'),
#  ('uglier', 'terrible'),
#  ('terrible', 'track'),
#  ('track', 'record'),
#  ('record', 'make'),
#  ('make', 'tempting'),
#  ('tempting', 'fade'),
#  ('fade', 'lump'),
#  ('lump', 'together'),
#  ('together', 'odd'),
#  ('odd', 'collection'),
#  ('collection', 'beer'),
#  ('beer', 'ipa'),
#  ('ipa', 'berliner'),
#  ('berliner', 'weisse'),
#  ('weisse', 'pilsener'),
#  ('pilsener', 'grätzer'),
#  ('grätzer', 'beer'),
#  ('beer', 'whose'),
#  ('whose', 'connection'),
#  ('connection', 'pale'),
#  ('pale', 'colour'),
#  ('colour', 'missed'),
#  ('missed', 'grätzer'),
#  ('grätzer', 'reference'),
#  ('reference', 'first'),
#  ('first', 'time'),
#  ('time', 'read'),
#  ('read', 'another'),
#  ('another', 'one'),
#  ('one', 'collection'),
#  ('collection', 'first'),
#  ('first', 'mention'),
#  ('mention', 'remember'),
#  ('remember', 'using'),
#  ('using', 'hop'),
#  ('hop', 'year'),
#  ('year', 'old'),
#  ('old', 'red'),
#  ('red', 'bell'),
#  ('bell', 'pepper'),
#  ('pepper', 'sliced'),
#  ('sliced', 'kathleen'),
#  ('kathleen', 'peacock'),
#  ('peacock', 'thrilling'),
#  ('thrilling', 'novel'),
#  ('novel', 'first'),
#  ('first', 'hemlock'),
#  ('hemlock', 'trilogy'),
#  ('trilogy', 'urban'),
#  ('urban', 'fantasy'),
#  ('fantasy', 'series'),
#  ('series', 'filled'),
#  ('filled', 'provocative'),
#  ('provocative', 'question'),
#  ('question', 'prejudice'),
#  ('prejudice', 'trust'),
#  ('trust', 'lie'),
#  ('lie', 'love'),
#  ('love', 'anyway'),
#  ('anyway', 'brought'),
#  ('brought', 'biscoff'),
#  ('biscoff', 'spread'),
#  ('spread', 'home'),
#  ('home', 'waited'),
#  ('waited', 'approximately'),
#  ('approximately', 'second'),
#  ('second', 'grabbing'),
#  ('grabbing', 'spoon'),
#  ('spoon', 'giving'),
#  ('giving', 'taste'),
#  ('taste', 'verdict'),
#  ('verdict', 'taste'),
#  ('taste', 'like'),
#  ('like', 'cooky'),
#  ('cooky', 'good'),
#  ('good', 'better'),
#  ('better', 'nutella'),
#  ('nutella', 'good'),
#  ('good', 'unfortunately'),
#  ('unfortunately', 'men'),
#  ('men', 'reached'),
#  ('reached', 'second'),
#  ('second', 'floor'),
#  ('floor', 'could'),
#  ('could', 'find'),
#  ('find', 'gun'),
#  ('gun', 'climbed'),
#  ('climbed', 'roof'),
#  ('roof', 'escape'),
#  ('escape', 'outside'),
#  ('outside', 'grandfather'),
#  ('grandfather', 'yard'),
#  ('yard', 'saw'),
#  ('saw', 'dad'),
#  ('dad', 'yard'),
#  ('yard', 'work'),
#  ('work', 'saw'),
#  ('saw', 'fictional'),
#  ('fictional', 'dog'),
#  ('dog', 'somehow'),
#  ('somehow', 'knew'),
#  ('knew', 'yelled'),
#  ('yelled', 'dad'),
#  ('dad', 'get'),
#  ('get', 'grandfather'),
#  ('grandfather', 'truck'),
#  ('truck', 'men'),
#  ('men', 'gun'),
#  ('gun', 'trying'),
#  ('trying', 'kill'),
#  ('kill', 'wrist'),
#  ('wrist', 'bind'),
#  ('bind', 'successful'),
#  ('successful', 'attack'),
#  ('attack', 'whipwhirl'),
#  ('whipwhirl', 'bind'),
#  ('bind', 'opponent'),
#  ('opponent', 'wrist'),
#  ('wrist', 'possibility'),
#  ('possibility', 'victim'),
#  ('victim', 'fumble'),
#  ('fumble', 'drop'),
#  ('drop', 'anything'),
#  ('anything', 'might'),
#  ('might', 'holding'),
#  ('holding', 'hand'),
#  ('hand', 'base'),
#  ('base', 'chance'),
#  ('chance', 'fumble'),
#  ('fumble', 'whipwhirl'),
#  ('whipwhirl', 'wrist'),
#  ('wrist', 'attack'),
#  ('attack', 'minus'),
#  ('minus', 'per'),
#  ('per', 'point'),
#  ('point', 'dexterity'),
#  ('dexterity', 'affected'),
#  ('affected', 'target'),
#  ('target', 'character'),
#  ('character', 'dexterity'),
#  ('dexterity', 'would'),
#  ('would', 'chance'),
#  ('chance', 'fumbling'),
#  ('fumbling', 'type'),
#  ('type', 'attack'),
#  ('attack', 'chris'),
#  ('chris', 'bye'),
#  ('bye', 'bye'),
#  ('bye', 'try'),
#  ('try', 'best'),
#  ('best', 'never'),
#  ('never', 'forget'),
#  ('forget', 'please'),
#  ('please', 'remember'),
#  ('remember', 'name'),
#  ('name', 'tell'),
#  ('tell', 'lol'),
#  ('lol', 'make'),
#  ('make', 'priority'),
#  ('priority', 'day'),
#  ('day', 'read'),
#  ('read', 'gratitude'),
#  ('gratitude', 'list'),
#  ('list', 'waking'),
#  ('waking', 'going'),
#  ('going', 'bed'),
#  ('bed', 'least'),
#  ('least', 'one'),
#  ('one', 'time'),
#  ('time', 'day'),
#  ('day', 'know'),
#  ('know', 'whether'),
#  ('whether', 'post'),
#  ('post', 'significance'),
#  ('significance', 'know'),
#  ('know', 'blessing'),
#  ('blessing', 'bountiful'),
#  ('bountiful', 'oz'),
#  ('oz', 'light'),
#  ('light', 'sour'),
#  ('sour', 'cream'),
#  ('cream', 'video'),
#  ('video', 'talk'),
#  ('talk', 'tip'),
#  ('tip', 'give'),
#  ('give', 'tour'),
#  ('tour', 'system'),
#  ('system', 'tried'),
#  ('tried', 'write'),
#  ('write', 'clearly'),
#  ('clearly', 'could'),
#  ('could', 'post'),
#  ('post', 'sometimes'),
#  ('sometimes', 'better'),
#  ('better', 'see'),
#  ('see', 'action'),
#  ('action', 'tough'),
#  ('tough', 'explain'),
#  ('explain', 'jf'),
#  ('jf', 'lot'),
#  ('lot', 'guideline'),
#  ('guideline', 'lot'),
#  ('lot', 'people'),
#  ('people', 'treat'),
#  ('treat', 'immutable'),
#  ('immutable', 'law'),
#  ('law', 'like'),
#  ('like', 'tell'),
#  ('tell', 'use'),
#  ('use', 'lot'),
#  ('lot', 'distraction'),
#  ('distraction', 'like'),
#  ('like', 'pt'),
#  ('pt', 'time'),
#  ('time', 'roman'),
#  ('roman', 'never'),
#  ('never', 'submitted'),
#  ('submitted', 'm'),
#  ('m', 'time'),
#  ('time', 'roman'),
#  ('roman', 'never'),
#  ('never', 'one'),
#  ('one', 'rejected'),
#  ('rejected', 'wrong'),
#  ('wrong', 'font'),
#  ('font', 'tell'),
#  ('tell', 'adrian'),
#  ('adrian', 'write'),
#  ('write', 'might'),
#  ('might', 'think'),
#  ('think', 'prescription'),
#  ('prescription', 'successful'),
#  ('successful', 'writing'),
#  ('writing', 'possibly'),
#  ('possibly', 'bad'),
#  ('bad', 'way'),
#  ('way', 'write'),
#  ('write', 'people'),
#  ('people', 'work'),
#  ('work', 'way'),
#  ('way', 'writing'),
#  ('writing', 'work'),
#  ('work', 'much'),
#  ('much', 'activity'),
#  ('activity', 'writing'),
#  ('writing', 'going'),
#  ('going', 'say'),
#  ('say', 'detailed'),
#  ('detailed', 'plan'),
#  ('plan', 'write'),
#  ('write', 'detailed'),
#  ('detailed', 'plan'),
#  ('plan', 'want'),
#  ('want', 'get'),
#  ('get', 'adrian'),
#  ('adrian', 'talk'),
#  ('talk', 'novel'),
#  ('novel', 'understand'),
#  ('understand', 'writing'),
#  ('writing', 'work'),
#  ('work', 'could'),
#  ('could', 'work'),
#  ('work', 'ask'),
#  ('ask', 'question'),
#  ('question', 'like'),
#  ('like', 'narrator'),
#  ('narrator', 'omniscient'),
#  ('omniscient', 'narrator'),
#  ('narrator', 'narrator'),
#  ('narrator', 'character'),
#  ('character', 'reliable'),
#  ('reliable', 'switch'),
#  ('switch', 'point'),
#  ('point', 'view'),
#  ('view', 'main'),
#  ('main', 'character'),
#  ('character', 'flaw'),
#  ('flaw', 'opinion'),
#  ('opinion', 'share'),
#  ('share', 'change'),
#  ('change', 'course'),
#  ('course', 'book'),
#  ('book', 'medium'),
#  ('medium', 'saucepan'),
#  ('saucepan', 'combine'),
#  ('combine', 'butter'),
#  ('butter', 'salt'),
#  ('salt', 'water'),
#  ('water', 'mexican'),
#  ('mexican', 'chocolate'),
#  ('chocolate', 'grated'),
#  ('grated', 'chop'),
#  ('chop', 'prefer'),
#  ('prefer', 'medium'),
#  ('medium', 'high'),
#  ('high', 'heat'),
#  ('heat', 'bring'),
#  ('bring', 'mixture'),
#  ('mixture', 'low'),
#  ('low', 'boil'),
#  ('boil', 'sure'),
#  ('sure', 'wondered'),
#  ('wondered', 'got'),
#  ('got', 'western'),
#  ('western', 'writing'),
#  ('writing', 'grew'),
#  ('grew', 'watching'),
#  ('watching', 'gunsmoke'),
#  ('gunsmoke', 'paladin'),
#  ('paladin', 'bonanza'),
#  ('bonanza', 'etc'),
#  ('etc', 'dad'),
#  ('dad', 'loved'),
#  ('loved', 'western'),
#  ('western', 'top'),
#  ('top', 'fact'),
#  ('fact', 'enjoy'),
#  ('enjoy', 'reading'),
#  ('reading', 'history'),
#  ('history', 'mind'),
#  ('mind', 'read'),
#  ('read', 'history'),
#  ('history', 'textbook'),
#  ('textbook', 'school'),
#  ('school', 'fact'),
#  ('fact', 'may'),
#  ('may', 'kid'),
#  ('kid', 'read'),
#  ('read', 'whole'),
#  ('whole', 'book'),
#  ('book', 'math'),
#  ('math', 'get'),
#  ('get', 'wrong'),
#  ('wrong', 'actually'),
#  ('actually', 'mind'),
#  ('mind', 'folding'),
#  ('folding', 'laundry'),
#  ('laundry', 'really'),
#  ('really', 'hate'),
#  ('hate', 'putting'),
#  ('putting', 'away'),
#  ('away', 'digress'),
#  ('digress', 'well'),
#  ('well', 'play'),
#  ('play', 'dungeon'),
#  ('dungeon', 'dragon'),
#  ('dragon', 'asking'),
#  ('asking', 'buy'),
#  ('buy', 'shirt'),
#  ('shirt', 'today'),
#  ('today', 'iraq'),
#  ('iraq', 'mosul'),
#  ('mosul', 'imam'),
#  ('imam', 'gunned'),
#  ('gunned', 'outside'),
#  ('outside', 'mosque'),
#  ('mosque', 'religion'),
#  ('religion', 'peace'),
#  ('peace', 'rival'),
#  ('rival', 'another'),
#  ('another', 'cool'),
#  ('cool', 'discovery'),
#  ('discovery', 'traif'),
#  ('traif', 'bike'),
#  ('bike', 'geshefton'),
#  ('geshefton', 'williamburg'),
#  ('williamburg', 'side'),
#  ('side', 'bridge'),
#  ('bridge', 'address'),
#  ('address', 'south'),
#  ('south', 'street'),
#  ('street', 'bedford'),
#  ('bedford', 'berry'),
#  ('berry', 'street'),
#  ('street', 'please'),
#  ('please', 'note'),
#  ('note', 'open'),
#  ('open', 'accept'),
#  ('accept', 'cash'),
#  ('cash', 'form'),
#  ('form', 'payment'),
#  ('payment', 'happen'),
#  ('happen', 'get'),
#  ('get', 'flat'),
#  ('flat', 'pump'),
#  ('pump', 'use'),
#  ('use', 'also'),
#  ('also', 'outside'),
#  ('outside', 'vending'),
#  ('vending', 'machine'),
#  ('machine', 'buy'),
#  ('buy', 'pump'),
#  ('pump', 'tire'),
#  ('tire', 'repair'),
#  ('repair', 'kit'),
#  ('kit', 'small'),
#  ('small', 'etc'),
#  ('etc', 'although'),
#  ('although', 'longer'),
#  ('longer', 'rent'),
#  ('rent', 'bike'),
#  ('bike', 'catch'),
#  ('catch', 'flat'),
#  ('flat', 'place'),
#  ('place', 'go'),
#  ('go', 'repair'),
#  ('repair', 'direction'),
#  ('direction', 'traif'),
#  ('traif', 'bike'),
#  ('bike', 'gesheft'),
#  ('gesheft', 'located'),
#  ('located', 'south'),
#  ('south', 'street'),
#  ('street', 'click'),
#  ('click', 'link'),
#  ('link', 'public'),
#  ('public', 'employee'),
#  ('employee', 'father'),
#  ('father', 'top'),
#  ('top', 'busy'),
#  ('busy', 'enjoying'),
#  ('enjoying', 'mother'),
#  ('mother', 'realized'),
#  ('realized', 'another'),
#  ('another', 'presence'),
#  ('presence', 'kind'),
#  ('kind', 'dad'),
#  ('dad', 'altho'),
#  ('altho', 'pure'),
#  ('pure', 'energy'),
#  ('energy', 'physical'),
#  ('physical', 'recognized'),
#  ('recognized', 'energy'),
#  ('energy', 'signature'),
#  ('signature', 'right'),
#  ('right', 'franklyn'),
#  ('franklyn', 'pleiadian'),
#  ('pleiadian', 'guide'),
#  ('guide', 'turn'),
#  ...]

# %% [markdown]
# ### N-Grams = 3

# %%
list(ngrams(tokens,3))
# Out:
# [('given', 'heart', 'away'),
#  ('heart', 'away', 'sordid'),
#  ('away', 'sordid', 'boon'),
#  ('sordid', 'boon', 'start'),
#  ('boon', 'start', 'side'),
#  ('start', 'side', 'sugar'),
#  ('side', 'sugar', 'sweet'),
#  ('sugar', 'sweet', 'asian'),
#  ('sweet', 'asian', 'community'),
#  ('asian', 'community', 'need'),
#  ('community', 'need', 'next'),
#  ('need', 'next', 'thing'),
#  ('next', 'thing', 'know'),
#  ('thing', 'know', 'asian'),
#  ('know', 'asian', 'kid'),
#  ('asian', 'kid', 'following'),
#  ('kid', 'following', 'around'),
#  ('following', 'around', 'know'),
#  ('around', 'know', 'shit'),
#  ('know', 'shit', 'boy'),
#  ('shit', 'boy', 'wanted'),
#  ('boy', 'wanted', 'inside'),
#  ('wanted', 'inside', 'especially'),
#  ('inside', 'especially', 'two'),
#  ('especially', 'two', 'particular'),
#  ('two', 'particular', 'thought'),
#  ('particular', 'thought', 'wonderful'),
#  ('thought', 'wonderful', 'sickened'),
#  ('wonderful', 'sickened', 'even'),
#  ('sickened', 'even', 'wonderful'),
#  ('even', 'wonderful', 'reminds'),
#  ('wonderful', 'reminds', 'quote'),
#  ('reminds', 'quote', 'wwii'),
#  ('quote', 'wwii', 'era'),
#  ('wwii', 'era', 'forget'),
#  ('era', 'forget', 'go'),
#  ('forget', 'go', 'say'),
#  ('go', 'say', 'something'),
#  ('say', 'something', 'like'),
#  ('something', 'like', 'hero'),
#  ('like', 'hero', 'everyone'),
#  ('hero', 'everyone', 'around'),
#  ('everyone', 'around', 'acting'),
#  ('around', 'acting', 'badly'),
#  ('acting', 'badly', 'someone'),
#  ('badly', 'someone', 'humanitarian'),
#  ('someone', 'humanitarian', 'award'),
#  ('humanitarian', 'award', 'nicholas'),
#  ('award', 'nicholas', 'brain'),
#  ('nicholas', 'brain', 'run'),
#  ('brain', 'run', 'excellent'),
#  ('run', 'excellent', 'processing'),
#  ('excellent', 'processing', 'data'),
#  ('processing', 'data', 'concrete'),
#  ('data', 'concrete', 'fact'),
#  ('concrete', 'fact', 'work'),
#  ('fact', 'work', 'best'),
#  ('work', 'best', 'thing'),
#  ('best', 'thing', 'quantify'),
#  ('thing', 'quantify', 'run'),
#  ('quantify', 'run', 'almost'),
#  ('run', 'almost', 'insurmountable'),
#  ('almost', 'insurmountable', 'challenge'),
#  ('insurmountable', 'challenge', 'trying'),
#  ('challenge', 'trying', 'rationalize'),
#  ('trying', 'rationalize', 'existence'),
#  ('rationalize', 'existence', 'exceptional'),
#  ('existence', 'exceptional', 'infant'),
#  ('exceptional', 'infant', 'daughter'),
#  ('infant', 'daughter', 'represents'),
#  ('daughter', 'represents', 'without'),
#  ('represents', 'without', 'sense'),
#  ('without', 'sense', 'humor'),
#  ('sense', 'humor', 'loving'),
#  ('humor', 'loving', 'forced'),
#  ('loving', 'forced', 'radically'),
#  ('forced', 'radically', 'confront'),
#  ('radically', 'confront', 'limitation'),
#  ('confront', 'limitation', 'speech'),
#  ('limitation', 'speech', 'economic'),
#  ('speech', 'economic', 'inequality'),
#  ('economic', 'inequality', 'reelection'),
#  ('inequality', 'reelection', 'game'),
#  ('reelection', 'game', 'dinner'),
#  ('game', 'dinner', 'taking'),
#  ('dinner', 'taking', 'picture'),
#  ('taking', 'picture', 'race'),
#  ('picture', 'race', 'outfit'),
#  ('race', 'outfit', 'sure'),
#  ('outfit', 'sure', 'see'),
#  ('sure', 'see', 'wore'),
#  ('see', 'wore', 'sunday'),
#  ('wore', 'sunday', 'wash'),
#  ('sunday', 'wash', 'right'),
#  ('wash', 'right', 'post'),
#  ('right', 'post', 'pic'),
#  ('post', 'pic', 'next'),
#  ('pic', 'next', 'day'),
#  ('next', 'day', 'heard'),
#  ('day', 'heard', 'loud'),
#  ('heard', 'loud', 'clear'),
#  ('loud', 'clear', 'family'),
#  ('clear', 'family', 'witness'),
#  ('family', 'witness', 'exclusion'),
#  ('witness', 'exclusion', 'apprehensive'),
#  ('exclusion', 'apprehensive', 'pusuited'),
#  ('apprehensive', 'pusuited', 'grandfather'),
#  ('pusuited', 'grandfather', 'decided'),
#  ('grandfather', 'decided', 'escape'),
#  ('decided', 'escape', 'germany'),
#  ('escape', 'germany', 'heading'),
#  ('germany', 'heading', 'britain'),
#  ('heading', 'britain', 'must'),
#  ('britain', 'must', 'never'),
#  ('must', 'never', 'happen'),
#  ('never', 'happen', 'andy'),
#  ('happen', 'andy', 'say'),
#  ('andy', 'say', 'tell'),
#  ('say', 'tell', 'worry'),
#  ('tell', 'worry', 'party'),
#  ('worry', 'party', 'europe'),
#  ('party', 'europe', 'seem'),
#  ('europe', 'seem', 'get'),
#  ('seem', 'get', 'popular'),
#  ('get', 'popular', 'strong'),
#  ('popular', 'strong', 'humble'),
#  ('strong', 'humble', 'steinberg'),
#  ('humble', 'steinberg', 'belief'),
#  ('steinberg', 'belief', 'light'),
#  ('belief', 'light', 'new'),
#  ('light', 'new', 'assessment'),
#  ('new', 'assessment', 'israeli'),
#  ('assessment', 'israeli', 'attack'),
#  ('israeli', 'attack', 'back'),
#  ('attack', 'back', 'burner'),
#  ('back', 'burner', 'thanks'),
#  ('burner', 'thanks', 'everyone'),
#  ('thanks', 'everyone', 'helped'),
#  ('everyone', 'helped', 'made'),
#  ('helped', 'made', 'art'),
#  ('made', 'art', 'domain'),
#  ('art', 'domain', 'success'),
#  ('domain', 'success', 'great'),
#  ('success', 'great', 'show'),
#  ('great', 'show', 'enthusiastic'),
#  ('show', 'enthusiastic', 'crowd'),
#  ('enthusiastic', 'crowd', 'everyone'),
#  ('crowd', 'everyone', 'already'),
#  ('everyone', 'already', 'looking'),
#  ('already', 'looking', 'forward'),
#  ('looking', 'forward', 'october'),
#  ('forward', 'october', 'show'),
#  ('october', 'show', 'domain'),
#  ('show', 'domain', 'sweet'),
#  ('domain', 'sweet', 'boy'),
#  ('sweet', 'boy', 'dote'),
#  ('boy', 'dote', 'quite'),
#  ('dote', 'quite', 'capable'),
#  ('quite', 'capable', 'resisting'),
#  ('capable', 'resisting', 'training'),
#  ('resisting', 'training', 'month'),
#  ('training', 'month', 'past'),
#  ('month', 'past', 'patience'),
#  ('past', 'patience', 'consistency'),
#  ('patience', 'consistency', 'called'),
#  ('consistency', 'called', 'win'),
#  ('called', 'win', 'day'),
#  ('win', 'day', 'end'),
#  ('day', 'end', 'might'),
#  ('end', 'might', 'decide'),
#  ('might', 'decide', 'get'),
#  ('decide', 'get', 'program'),
#  ('get', 'program', 'week'),
#  ('program', 'week', 'might'),
#  ('week', 'might', 'month'),
#  ('might', 'month', 'time'),
#  ('month', 'time', 'tell'),
#  ('time', 'tell', 'think'),
#  ('tell', 'think', 'know'),
#  ('think', 'know', 'likely'),
#  ('know', 'likely', 'response'),
#  ('likely', 'response', 'training'),
#  ('response', 'training', 'go'),
#  ('training', 'go', 'new'),
#  ('go', 'new', 'level'),
#  ('new', 'level', 'reason'),
#  ('level', 'reason', 'initially'),
#  ('reason', 'initially', 'investigate'),
#  ('initially', 'investigate', 'catalogue'),
#  ('investigate', 'catalogue', 'one'),
#  ('catalogue', 'one', 'friday'),
#  ('one', 'friday', 'work'),
#  ('friday', 'work', 'talking'),
#  ('work', 'talking', 'another'),
#  ('talking', 'another', 'friend'),
#  ('another', 'friend', 'loved'),
#  ('friend', 'loved', 'ann'),
#  ('loved', 'ann', 'peebles'),
#  ('ann', 'peebles', 'next'),
#  ('peebles', 'next', 'day'),
#  ('next', 'day', 'way'),
#  ('day', 'way', 'town'),
#  ('way', 'town', 'shop'),
#  ('town', 'shop', 'decided'),
#  ('shop', 'decided', 'simply'),
#  ('decided', 'simply', 'buy'),
#  ('simply', 'buy', 'peebles'),
#  ('buy', 'peebles', 'record'),
#  ('peebles', 'record', 'first'),
#  ('record', 'first', 'stop'),
#  ('first', 'stop', 'reckless'),
#  ('stop', 'reckless', 'berwick'),
#  ('reckless', 'berwick', 'st'),
#  ('berwick', 'st', 'still'),
#  ('st', 'still', 'basement'),
#  ('still', 'basement', 'box'),
#  ('basement', 'box', 'soul'),
#  ('box', 'soul', 'single'),
#  ('soul', 'single', 'sat'),
#  ('single', 'sat', 'counter'),
#  ('sat', 'counter', 'inherited'),
#  ('counter', 'inherited', 'dad'),
#  ('inherited', 'dad', 'hoarding'),
#  ('dad', 'hoarding', 'tendency'),
#  ('hoarding', 'tendency', 'acute'),
#  ('tendency', 'acute', 'sense'),
#  ('acute', 'sense', 'relative'),
#  ('sense', 'relative', 'value'),
#  ('relative', 'value', 'never'),
#  ('value', 'never', 'bought'),
#  ('never', 'bought', 'many'),
#  ('bought', 'many', 'must'),
#  ('many', 'must', 'trendily'),
#  ('must', 'trendily', 'refer'),
#  ('trendily', 'refer', 'time'),
#  ('refer', 'time', 'deliberately'),
#  ('time', 'deliberately', 'avoid'),
#  ('deliberately', 'avoid', 'looking'),
#  ('avoid', 'looking', 'beyond'),
#  ('looking', 'beyond', 'lp'),
#  ('beyond', 'lp', 'section'),
#  ('lp', 'section', 'shop'),
#  ('section', 'shop', 'mission'),
#  ('shop', 'mission', 'time'),
#  ('mission', 'time', 'though'),
#  ('time', 'though', 'miraculously'),
#  ('though', 'miraculously', 'began'),
#  ('miraculously', 'began', 'flick'),
#  ('began', 'flick', 'second'),
#  ('flick', 'second', 'record'),
#  ('second', 'record', 'box'),
#  ('record', 'box', 'willed'),
#  ('box', 'willed', 'excitedly'),
#  ('willed', 'excitedly', 'parted'),
#  ('excitedly', 'parted', 'memory'),
#  ('parted', 'memory', 'anything'),
#  ('memory', 'anything', 'else'),
#  ('anything', 'else', 'bought'),
#  ('else', 'bought', 'day'),
#  ('bought', 'day', 'remember'),
#  ('day', 'remember', 'definitely'),
#  ('remember', 'definitely', 'raining'),
#  ('definitely', 'raining', 'getting'),
#  ('raining', 'getting', 'record'),
#  ('getting', 'record', 'home'),
#  ('record', 'home', 'bonus'),
#  ('home', 'bonus', 'discovery'),
#  ('bonus', 'discovery', 'equally'),
#  ('discovery', 'equally', 'brilliant'),
#  ('equally', 'brilliant', 'part'),
#  ('brilliant', 'part', 'whose'),
#  ('part', 'whose', 'intro'),
#  ('whose', 'intro', 'backbone'),
#  ('intro', 'backbone', 'gza'),
#  ('backbone', 'gza', 'track'),
#  ('gza', 'track', 'bit'),
#  ('track', 'bit', 'obsessed'),
#  ('bit', 'obsessed', 'time'),
#  ('obsessed', 'time', 'huge'),
#  ('time', 'huge', 'proportion'),
#  ('huge', 'proportion', 'early'),
#  ('proportion', 'early', 'rza'),
#  ('early', 'rza', 'production'),
#  ('rza', 'production', 'relies'),
#  ('production', 'relies', 'hi'),
#  ('relies', 'hi', 'back'),
#  ('hi', 'back', 'catalogue'),
#  ('back', 'catalogue', 'contrast'),
#  ('catalogue', 'contrast', 'song'),
#  ('contrast', 'song', 'much'),
#  ('song', 'much', 'positive'),
#  ('much', 'positive', 'title'),
#  ('positive', 'title', 'indicates'),
#  ('title', 'indicates', 'bidding'),
#  ('indicates', 'bidding', 'goodbye'),
#  ('bidding', 'goodbye', 'trouble'),
#  ('goodbye', 'trouble', 'sadness'),
#  ('trouble', 'sadness', 'rather'),
#  ('sadness', 'rather', 'customary'),
#  ('rather', 'customary', 'peebles'),
#  ('customary', 'peebles', 'telling'),
#  ('peebles', 'telling', 'piss'),
#  ('telling', 'piss', 'forest'),
#  ('piss', 'forest', 'city'),
#  ('forest', 'city', 'ratner'),
#  ('city', 'ratner', 'company'),
#  ('ratner', 'company', 'brooklyn'),
#  ('company', 'brooklyn', 'event'),
#  ('brooklyn', 'event', 'center'),
#  ('event', 'center', 'subsidiary'),
#  ('center', 'subsidiary', 'would'),
#  ('subsidiary', 'would', 'tiny'),
#  ('would', 'tiny', 'fraction'),
#  ('tiny', 'fraction', 'job'),
#  ('fraction', 'job', 'would'),
#  ('job', 'would', 'hired'),
#  ('would', 'hired', 'aeg'),
#  ('hired', 'aeg', 'charge'),
#  ('aeg', 'charge', 'arena'),
#  ('charge', 'arena', 'operation'),
#  ('arena', 'operation', 'hired'),
#  ('operation', 'hired', 'levy'),
#  ('hired', 'levy', 'restaurant'),
#  ('levy', 'restaurant', 'charge'),
#  ('restaurant', 'charge', 'food'),
#  ('charge', 'food', 'service'),
#  ('food', 'service', 'exciting'),
#  ('service', 'exciting', 'news'),
#  ('exciting', 'news', 'august'),
#  ('news', 'august', 'sweet'),
#  ('august', 'sweet', 'baby'),
#  ('sweet', 'baby', 'jane'),
#  ('baby', 'jane', 'joined'),
#  ('jane', 'joined', 'family'),
#  ('joined', 'family', 'born'),
#  ('family', 'born', 'hour'),
#  ('born', 'hour', 'labor'),
#  ('hour', 'labor', 'much'),
#  ('labor', 'much', 'better'),
#  ('much', 'better', 'annabelle'),
#  ('better', 'annabelle', 'hour'),
#  ('annabelle', 'hour', 'labor'),
#  ('hour', 'labor', 'long'),
#  ('labor', 'long', 'jane'),
#  ('long', 'jane', 'look'),
#  ('jane', 'look', 'lot'),
#  ('look', 'lot', 'like'),
#  ('lot', 'like', 'annabelle'),
#  ('like', 'annabelle', 'baby'),
#  ('annabelle', 'baby', 'definitely'),
#  ('baby', 'definitely', 'personality'),
#  ('definitely', 'personality', 'happy'),
#  ('personality', 'happy', 'sweet'),
#  ('happy', 'sweet', 'baby'),
#  ('sweet', 'baby', 'girl'),
#  ('baby', 'girl', 'could'),
#  ('girl', 'could', 'join'),
#  ('could', 'join', 'family'),
#  ('join', 'family', 'annabelle'),
#  ('family', 'annabelle', 'love'),
#  ('annabelle', 'love', 'new'),
#  ('love', 'new', 'little'),
#  ('new', 'little', 'sister'),
#  ('little', 'sister', 'jane'),
#  ('sister', 'jane', 'little'),
#  ('jane', 'little', 'live'),
#  ('little', 'live', 'wire'),
#  ('live', 'wire', 'right'),
#  ('wire', 'right', 'jane'),
#  ('right', 'jane', 'born'),
#  ('jane', 'born', 'could'),
#  ('born', 'could', 'lift'),
#  ('could', 'lift', 'head'),
#  ('lift', 'head', 'always'),
#  ('head', 'always', 'moving'),
#  ('always', 'moving', 'cuddly'),
#  ('moving', 'cuddly', 'baby'),
#  ('cuddly', 'baby', 'like'),
#  ('baby', 'like', 'annabelle'),
#  ('like', 'annabelle', 'still'),
#  ('annabelle', 'still', 'sweet'),
#  ('still', 'sweet', 'happy'),
#  ('sweet', 'happy', 'little'),
#  ('happy', 'little', 'one'),
#  ('little', 'one', 'move'),
#  ('one', 'move', 'much'),
#  ('move', 'much', 'learned'),
#  ('much', 'learned', 'roll'),
#  ('learned', 'roll', 'month'),
#  ('roll', 'month', 'month'),
#  ('month', 'month', 'army'),
#  ('month', 'army', 'crawling'),
#  ('army', 'crawling', 'everywhere'),
#  ('crawling', 'everywhere', 'crazy'),
#  ('everywhere', 'crazy', 'huh'),
#  ('crazy', 'huh', 'little'),
#  ('huh', 'little', 'determined'),
#  ('little', 'determined', 'one'),
#  ('determined', 'one', 'probably'),
#  ('one', 'probably', 'going'),
#  ('probably', 'going', 'walk'),
#  ('going', 'walk', 'soon'),
#  ('walk', 'soon', 'swear'),
#  ('soon', 'swear', 'jane'),
#  ('swear', 'jane', 'month'),
#  ('jane', 'month', 'dr'),
#  ('month', 'dr', 'appointment'),
#  ('dr', 'appointment', 'weighed'),
#  ('appointment', 'weighed', 'lb'),
#  ('weighed', 'lb', 'oz'),
#  ('lb', 'oz', 'make'),
#  ('oz', 'make', 'percentile'),
#  ('make', 'percentile', 'little'),
#  ('percentile', 'little', 'one'),
#  ('little', 'one', 'probably'),
#  ('one', 'probably', 'move'),
#  ('probably', 'move', 'time'),
#  ('move', 'time', 'annabelle'),
#  ('time', 'annabelle', 'good'),
#  ('annabelle', 'good', 'big'),
#  ('good', 'big', 'sister'),
#  ('big', 'sister', 'love'),
#  ('sister', 'love', 'make'),
#  ('love', 'make', 'laugh'),
#  ('make', 'laugh', 'sad'),
#  ('laugh', 'sad', 'give'),
#  ('sad', 'give', 'toy'),
#  ('give', 'toy', 'try'),
#  ('toy', 'try', 'everything'),
#  ('try', 'everything', 'make'),
#  ('everything', 'make', 'happy'),
#  ('make', 'happy', 'moment'),
#  ('happy', 'moment', 'hear'),
#  ('moment', 'hear', 'jane'),
#  ('hear', 'jane', 'cry'),
#  ('jane', 'cry', 'see'),
#  ('cry', 'see', 'annabelle'),
#  ('see', 'annabelle', 'trying'),
#  ('annabelle', 'trying', 'ride'),
#  ('trying', 'ride', 'back'),
#  ('ride', 'back', 'like'),
#  ('back', 'like', 'daddy'),
#  ('like', 'daddy', 'guess'),
#  ('daddy', 'guess', 'big'),
#  ('guess', 'big', 'sister'),
#  ('big', 'sister', 'get'),
#  ('sister', 'get', 'kind'),
#  ('get', 'kind', 'crazy'),
#  ('kind', 'crazy', 'mom'),
#  ('crazy', 'mom', 'two'),
#  ('mom', 'two', 'love'),
#  ('two', 'love', 'always'),
#  ('love', 'always', 'adventure'),
#  ('always', 'adventure', 'act'),
#  ('adventure', 'act', 'color'),
#  ('act', 'color', 'law'),
#  ('color', 'law', 'include'),
#  ('law', 'include', 'act'),
#  ('include', 'act', 'done'),
#  ('act', 'done', 'federal'),
#  ('done', 'federal', 'state'),
#  ('federal', 'state', 'local'),
#  ('state', 'local', 'official'),
#  ('local', 'official', 'within'),
#  ('official', 'within', 'bound'),
#  ('within', 'bound', 'limit'),
#  ('bound', 'limit', 'lawful'),
#  ('limit', 'lawful', 'authority'),
#  ('lawful', 'authority', 'also'),
#  ('authority', 'also', 'act'),
#  ('also', 'act', 'done'),
#  ('act', 'done', 'without'),
#  ('done', 'without', 'beyond'),
#  ('without', 'beyond', 'bound'),
#  ('beyond', 'bound', 'lawful'),
#  ('bound', 'lawful', 'authority'),
#  ('lawful', 'authority', 'provided'),
#  ('authority', 'provided', 'order'),
#  ('provided', 'order', 'unlawful'),
#  ('order', 'unlawful', 'act'),
#  ('unlawful', 'act', 'official'),
#  ('act', 'official', 'done'),
#  ('official', 'done', 'color'),
#  ('done', 'color', 'law'),
#  ('color', 'law', 'unlawful'),
#  ('law', 'unlawful', 'act'),
#  ('unlawful', 'act', 'must'),
#  ('act', 'must', 'done'),
#  ('must', 'done', 'official'),
#  ('done', 'official', 'purporting'),
#  ('official', 'purporting', 'pretending'),
#  ('purporting', 'pretending', 'act'),
#  ('pretending', 'act', 'performance'),
#  ('act', 'performance', 'official'),
#  ('performance', 'official', 'duty'),
#  ('official', 'duty', 'definition'),
#  ('duty', 'definition', 'includes'),
#  ('definition', 'includes', 'addition'),
#  ('includes', 'addition', 'law'),
#  ('addition', 'law', 'enforcement'),
#  ('law', 'enforcement', 'official'),
#  ('enforcement', 'official', 'individual'),
#  ('official', 'individual', 'mayor'),
#  ('individual', 'mayor', 'council'),
#  ('mayor', 'council', 'person'),
#  ('council', 'person', 'judge'),
#  ('person', 'judge', 'nursing'),
#  ('judge', 'nursing', 'home'),
#  ('nursing', 'home', 'proprietor'),
#  ('home', 'proprietor', 'security'),
#  ('proprietor', 'security', 'guard'),
#  ('security', 'guard', 'person'),
#  ('guard', 'person', 'bound'),
#  ('person', 'bound', 'law'),
#  ('bound', 'law', 'statute'),
#  ('law', 'statute', 'ordinance'),
#  ('statute', 'ordinance', 'custom'),
#  ('ordinance', 'custom', 'god'),
#  ('custom', 'god', 'love'),
#  ('god', 'love', 'drunkard'),
#  ('love', 'drunkard', 'cry'),
#  ('drunkard', 'cry', 'firm'),
#  ('cry', 'firm', 'trimtabs'),
#  ('firm', 'trimtabs', 'taking'),
#  ('trimtabs', 'taking', 'cautious'),
#  ('taking', 'cautious', 'stance'),
#  ('cautious', 'stance', 'reducing'),
#  ('stance', 'reducing', 'market'),
#  ('reducing', 'market', 'exposure'),
#  ('market', 'exposure', 'zero'),
#  ('exposure', 'zero', 'exposure'),
#  ('zero', 'exposure', 'trimtabs'),
#  ('exposure', 'trimtabs', 'reasoning'),
#  ('trimtabs', 'reasoning', 'end'),
#  ('reasoning', 'end', 'spell'),
#  ('end', 'spell', 'end'),
#  ('spell', 'end', 'propping'),
#  ('end', 'propping', 'market'),
#  ('propping', 'market', 'certainly'),
#  ('market', 'certainly', 'understandable'),
#  ('certainly', 'understandable', 'information'),
#  ('understandable', 'information', 'well'),
#  ('information', 'well', 'known'),
#  ('well', 'known', 'already'),
#  ('known', 'already', 'priced'),
#  ('already', 'priced', 'market'),
#  ('priced', 'market', 'go'),
#  ('market', 'go', 'write'),
#  ('go', 'write', 'client'),
#  ('write', 'client', 'p'),
#  ('client', 'p', 'interim'),
#  ('p', 'interim', 'closing'),
#  ('interim', 'closing', 'high'),
#  ('closing', 'high', 'april'),
#  ('high', 'april', 'expect'),
#  ('april', 'expect', 'market'),
#  ('expect', 'market', 'action'),
#  ('market', 'action', 'get'),
#  ('action', 'get', 'even'),
#  ('get', 'even', 'uglier'),
#  ('even', 'uglier', 'terrible'),
#  ('uglier', 'terrible', 'track'),
#  ('terrible', 'track', 'record'),
#  ('track', 'record', 'make'),
#  ('record', 'make', 'tempting'),
#  ('make', 'tempting', 'fade'),
#  ('tempting', 'fade', 'lump'),
#  ('fade', 'lump', 'together'),
#  ('lump', 'together', 'odd'),
#  ('together', 'odd', 'collection'),
#  ('odd', 'collection', 'beer'),
#  ('collection', 'beer', 'ipa'),
#  ('beer', 'ipa', 'berliner'),
#  ('ipa', 'berliner', 'weisse'),
#  ('berliner', 'weisse', 'pilsener'),
#  ('weisse', 'pilsener', 'grätzer'),
#  ('pilsener', 'grätzer', 'beer'),
#  ('grätzer', 'beer', 'whose'),
#  ('beer', 'whose', 'connection'),
#  ('whose', 'connection', 'pale'),
#  ('connection', 'pale', 'colour'),
#  ('pale', 'colour', 'missed'),
#  ('colour', 'missed', 'grätzer'),
#  ('missed', 'grätzer', 'reference'),
#  ('grätzer', 'reference', 'first'),
#  ('reference', 'first', 'time'),
#  ('first', 'time', 'read'),
#  ('time', 'read', 'another'),
#  ('read', 'another', 'one'),
#  ('another', 'one', 'collection'),
#  ('one', 'collection', 'first'),
#  ('collection', 'first', 'mention'),
#  ('first', 'mention', 'remember'),
#  ('mention', 'remember', 'using'),
#  ('remember', 'using', 'hop'),
#  ('using', 'hop', 'year'),
#  ('hop', 'year', 'old'),
#  ('year', 'old', 'red'),
#  ('old', 'red', 'bell'),
#  ('red', 'bell', 'pepper'),
#  ('bell', 'pepper', 'sliced'),
#  ('pepper', 'sliced', 'kathleen'),
#  ('sliced', 'kathleen', 'peacock'),
#  ('kathleen', 'peacock', 'thrilling'),
#  ('peacock', 'thrilling', 'novel'),
#  ('thrilling', 'novel', 'first'),
#  ('novel', 'first', 'hemlock'),
#  ('first', 'hemlock', 'trilogy'),
#  ('hemlock', 'trilogy', 'urban'),
#  ('trilogy', 'urban', 'fantasy'),
#  ('urban', 'fantasy', 'series'),
#  ('fantasy', 'series', 'filled'),
#  ('series', 'filled', 'provocative'),
#  ('filled', 'provocative', 'question'),
#  ('provocative', 'question', 'prejudice'),
#  ('question', 'prejudice', 'trust'),
#  ('prejudice', 'trust', 'lie'),
#  ('trust', 'lie', 'love'),
#  ('lie', 'love', 'anyway'),
#  ('love', 'anyway', 'brought'),
#  ('anyway', 'brought', 'biscoff'),
#  ('brought', 'biscoff', 'spread'),
#  ('biscoff', 'spread', 'home'),
#  ('spread', 'home', 'waited'),
#  ('home', 'waited', 'approximately'),
#  ('waited', 'approximately', 'second'),
#  ('approximately', 'second', 'grabbing'),
#  ('second', 'grabbing', 'spoon'),
#  ('grabbing', 'spoon', 'giving'),
#  ('spoon', 'giving', 'taste'),
#  ('giving', 'taste', 'verdict'),
#  ('taste', 'verdict', 'taste'),
#  ('verdict', 'taste', 'like'),
#  ('taste', 'like', 'cooky'),
#  ('like', 'cooky', 'good'),
#  ('cooky', 'good', 'better'),
#  ('good', 'better', 'nutella'),
#  ('better', 'nutella', 'good'),
#  ('nutella', 'good', 'unfortunately'),
#  ('good', 'unfortunately', 'men'),
#  ('unfortunately', 'men', 'reached'),
#  ('men', 'reached', 'second'),
#  ('reached', 'second', 'floor'),
#  ('second', 'floor', 'could'),
#  ('floor', 'could', 'find'),
#  ('could', 'find', 'gun'),
#  ('find', 'gun', 'climbed'),
#  ('gun', 'climbed', 'roof'),
#  ('climbed', 'roof', 'escape'),
#  ('roof', 'escape', 'outside'),
#  ('escape', 'outside', 'grandfather'),
#  ('outside', 'grandfather', 'yard'),
#  ('grandfather', 'yard', 'saw'),
#  ('yard', 'saw', 'dad'),
#  ('saw', 'dad', 'yard'),
#  ('dad', 'yard', 'work'),
#  ('yard', 'work', 'saw'),
#  ('work', 'saw', 'fictional'),
#  ('saw', 'fictional', 'dog'),
#  ('fictional', 'dog', 'somehow'),
#  ('dog', 'somehow', 'knew'),
#  ('somehow', 'knew', 'yelled'),
#  ('knew', 'yelled', 'dad'),
#  ('yelled', 'dad', 'get'),
#  ('dad', 'get', 'grandfather'),
#  ('get', 'grandfather', 'truck'),
#  ('grandfather', 'truck', 'men'),
#  ('truck', 'men', 'gun'),
#  ('men', 'gun', 'trying'),
#  ('gun', 'trying', 'kill'),
#  ('trying', 'kill', 'wrist'),
#  ('kill', 'wrist', 'bind'),
#  ('wrist', 'bind', 'successful'),
#  ('bind', 'successful', 'attack'),
#  ('successful', 'attack', 'whipwhirl'),
#  ('attack', 'whipwhirl', 'bind'),
#  ('whipwhirl', 'bind', 'opponent'),
#  ('bind', 'opponent', 'wrist'),
#  ('opponent', 'wrist', 'possibility'),
#  ('wrist', 'possibility', 'victim'),
#  ('possibility', 'victim', 'fumble'),
#  ('victim', 'fumble', 'drop'),
#  ('fumble', 'drop', 'anything'),
#  ('drop', 'anything', 'might'),
#  ('anything', 'might', 'holding'),
#  ('might', 'holding', 'hand'),
#  ('holding', 'hand', 'base'),
#  ('hand', 'base', 'chance'),
#  ('base', 'chance', 'fumble'),
#  ('chance', 'fumble', 'whipwhirl'),
#  ('fumble', 'whipwhirl', 'wrist'),
#  ('whipwhirl', 'wrist', 'attack'),
#  ('wrist', 'attack', 'minus'),
#  ('attack', 'minus', 'per'),
#  ('minus', 'per', 'point'),
#  ('per', 'point', 'dexterity'),
#  ('point', 'dexterity', 'affected'),
#  ('dexterity', 'affected', 'target'),
#  ('affected', 'target', 'character'),
#  ('target', 'character', 'dexterity'),
#  ('character', 'dexterity', 'would'),
#  ('dexterity', 'would', 'chance'),
#  ('would', 'chance', 'fumbling'),
#  ('chance', 'fumbling', 'type'),
#  ('fumbling', 'type', 'attack'),
#  ('type', 'attack', 'chris'),
#  ('attack', 'chris', 'bye'),
#  ('chris', 'bye', 'bye'),
#  ('bye', 'bye', 'try'),
#  ('bye', 'try', 'best'),
#  ('try', 'best', 'never'),
#  ('best', 'never', 'forget'),
#  ('never', 'forget', 'please'),
#  ('forget', 'please', 'remember'),
#  ('please', 'remember', 'name'),
#  ('remember', 'name', 'tell'),
#  ('name', 'tell', 'lol'),
#  ('tell', 'lol', 'make'),
#  ('lol', 'make', 'priority'),
#  ('make', 'priority', 'day'),
#  ('priority', 'day', 'read'),
#  ('day', 'read', 'gratitude'),
#  ('read', 'gratitude', 'list'),
#  ('gratitude', 'list', 'waking'),
#  ('list', 'waking', 'going'),
#  ('waking', 'going', 'bed'),
#  ('going', 'bed', 'least'),
#  ('bed', 'least', 'one'),
#  ('least', 'one', 'time'),
#  ('one', 'time', 'day'),
#  ('time', 'day', 'know'),
#  ('day', 'know', 'whether'),
#  ('know', 'whether', 'post'),
#  ('whether', 'post', 'significance'),
#  ('post', 'significance', 'know'),
#  ('significance', 'know', 'blessing'),
#  ('know', 'blessing', 'bountiful'),
#  ('blessing', 'bountiful', 'oz'),
#  ('bountiful', 'oz', 'light'),
#  ('oz', 'light', 'sour'),
#  ('light', 'sour', 'cream'),
#  ('sour', 'cream', 'video'),
#  ('cream', 'video', 'talk'),
#  ('video', 'talk', 'tip'),
#  ('talk', 'tip', 'give'),
#  ('tip', 'give', 'tour'),
#  ('give', 'tour', 'system'),
#  ('tour', 'system', 'tried'),
#  ('system', 'tried', 'write'),
#  ('tried', 'write', 'clearly'),
#  ('write', 'clearly', 'could'),
#  ('clearly', 'could', 'post'),
#  ('could', 'post', 'sometimes'),
#  ('post', 'sometimes', 'better'),
#  ('sometimes', 'better', 'see'),
#  ('better', 'see', 'action'),
#  ('see', 'action', 'tough'),
#  ('action', 'tough', 'explain'),
#  ('tough', 'explain', 'jf'),
#  ('explain', 'jf', 'lot'),
#  ('jf', 'lot', 'guideline'),
#  ('lot', 'guideline', 'lot'),
#  ('guideline', 'lot', 'people'),
#  ('lot', 'people', 'treat'),
#  ('people', 'treat', 'immutable'),
#  ('treat', 'immutable', 'law'),
#  ('immutable', 'law', 'like'),
#  ('law', 'like', 'tell'),
#  ('like', 'tell', 'use'),
#  ('tell', 'use', 'lot'),
#  ('use', 'lot', 'distraction'),
#  ('lot', 'distraction', 'like'),
#  ('distraction', 'like', 'pt'),
#  ('like', 'pt', 'time'),
#  ('pt', 'time', 'roman'),
#  ('time', 'roman', 'never'),
#  ('roman', 'never', 'submitted'),
#  ('never', 'submitted', 'm'),
#  ('submitted', 'm', 'time'),
#  ('m', 'time', 'roman'),
#  ('time', 'roman', 'never'),
#  ('roman', 'never', 'one'),
#  ('never', 'one', 'rejected'),
#  ('one', 'rejected', 'wrong'),
#  ('rejected', 'wrong', 'font'),
#  ('wrong', 'font', 'tell'),
#  ('font', 'tell', 'adrian'),
#  ('tell', 'adrian', 'write'),
#  ('adrian', 'write', 'might'),
#  ('write', 'might', 'think'),
#  ('might', 'think', 'prescription'),
#  ('think', 'prescription', 'successful'),
#  ('prescription', 'successful', 'writing'),
#  ('successful', 'writing', 'possibly'),
#  ('writing', 'possibly', 'bad'),
#  ('possibly', 'bad', 'way'),
#  ('bad', 'way', 'write'),
#  ('way', 'write', 'people'),
#  ('write', 'people', 'work'),
#  ('people', 'work', 'way'),
#  ('work', 'way', 'writing'),
#  ('way', 'writing', 'work'),
#  ('writing', 'work', 'much'),
#  ('work', 'much', 'activity'),
#  ('much', 'activity', 'writing'),
#  ('activity', 'writing', 'going'),
#  ('writing', 'going', 'say'),
#  ('going', 'say', 'detailed'),
#  ('say', 'detailed', 'plan'),
#  ('detailed', 'plan', 'write'),
#  ('plan', 'write', 'detailed'),
#  ('write', 'detailed', 'plan'),
#  ('detailed', 'plan', 'want'),
#  ('plan', 'want', 'get'),
#  ('want', 'get', 'adrian'),
#  ('get', 'adrian', 'talk'),
#  ('adrian', 'talk', 'novel'),
#  ('talk', 'novel', 'understand'),
#  ('novel', 'understand', 'writing'),
#  ('understand', 'writing', 'work'),
#  ('writing', 'work', 'could'),
#  ('work', 'could', 'work'),
#  ('could', 'work', 'ask'),
#  ('work', 'ask', 'question'),
#  ('ask', 'question', 'like'),
#  ('question', 'like', 'narrator'),
#  ('like', 'narrator', 'omniscient'),
#  ('narrator', 'omniscient', 'narrator'),
#  ('omniscient', 'narrator', 'narrator'),
#  ('narrator', 'narrator', 'character'),
#  ('narrator', 'character', 'reliable'),
#  ('character', 'reliable', 'switch'),
#  ('reliable', 'switch', 'point'),
#  ('switch', 'point', 'view'),
#  ('point', 'view', 'main'),
#  ('view', 'main', 'character'),
#  ('main', 'character', 'flaw'),
#  ('character', 'flaw', 'opinion'),
#  ('flaw', 'opinion', 'share'),
#  ('opinion', 'share', 'change'),
#  ('share', 'change', 'course'),
#  ('change', 'course', 'book'),
#  ('course', 'book', 'medium'),
#  ('book', 'medium', 'saucepan'),
#  ('medium', 'saucepan', 'combine'),
#  ('saucepan', 'combine', 'butter'),
#  ('combine', 'butter', 'salt'),
#  ('butter', 'salt', 'water'),
#  ('salt', 'water', 'mexican'),
#  ('water', 'mexican', 'chocolate'),
#  ('mexican', 'chocolate', 'grated'),
#  ('chocolate', 'grated', 'chop'),
#  ('grated', 'chop', 'prefer'),
#  ('chop', 'prefer', 'medium'),
#  ('prefer', 'medium', 'high'),
#  ('medium', 'high', 'heat'),
#  ('high', 'heat', 'bring'),
#  ('heat', 'bring', 'mixture'),
#  ('bring', 'mixture', 'low'),
#  ('mixture', 'low', 'boil'),
#  ('low', 'boil', 'sure'),
#  ('boil', 'sure', 'wondered'),
#  ('sure', 'wondered', 'got'),
#  ('wondered', 'got', 'western'),
#  ('got', 'western', 'writing'),
#  ('western', 'writing', 'grew'),
#  ('writing', 'grew', 'watching'),
#  ('grew', 'watching', 'gunsmoke'),
#  ('watching', 'gunsmoke', 'paladin'),
#  ('gunsmoke', 'paladin', 'bonanza'),
#  ('paladin', 'bonanza', 'etc'),
#  ('bonanza', 'etc', 'dad'),
#  ('etc', 'dad', 'loved'),
#  ('dad', 'loved', 'western'),
#  ('loved', 'western', 'top'),
#  ('western', 'top', 'fact'),
#  ('top', 'fact', 'enjoy'),
#  ('fact', 'enjoy', 'reading'),
#  ('enjoy', 'reading', 'history'),
#  ('reading', 'history', 'mind'),
#  ('history', 'mind', 'read'),
#  ('mind', 'read', 'history'),
#  ('read', 'history', 'textbook'),
#  ('history', 'textbook', 'school'),
#  ('textbook', 'school', 'fact'),
#  ('school', 'fact', 'may'),
#  ('fact', 'may', 'kid'),
#  ('may', 'kid', 'read'),
#  ('kid', 'read', 'whole'),
#  ('read', 'whole', 'book'),
#  ('whole', 'book', 'math'),
#  ('book', 'math', 'get'),
#  ('math', 'get', 'wrong'),
#  ('get', 'wrong', 'actually'),
#  ('wrong', 'actually', 'mind'),
#  ('actually', 'mind', 'folding'),
#  ('mind', 'folding', 'laundry'),
#  ('folding', 'laundry', 'really'),
#  ('laundry', 'really', 'hate'),
#  ('really', 'hate', 'putting'),
#  ('hate', 'putting', 'away'),
#  ('putting', 'away', 'digress'),
#  ('away', 'digress', 'well'),
#  ('digress', 'well', 'play'),
#  ('well', 'play', 'dungeon'),
#  ('play', 'dungeon', 'dragon'),
#  ('dungeon', 'dragon', 'asking'),
#  ('dragon', 'asking', 'buy'),
#  ('asking', 'buy', 'shirt'),
#  ('buy', 'shirt', 'today'),
#  ('shirt', 'today', 'iraq'),
#  ('today', 'iraq', 'mosul'),
#  ('iraq', 'mosul', 'imam'),
#  ('mosul', 'imam', 'gunned'),
#  ('imam', 'gunned', 'outside'),
#  ('gunned', 'outside', 'mosque'),
#  ('outside', 'mosque', 'religion'),
#  ('mosque', 'religion', 'peace'),
#  ('religion', 'peace', 'rival'),
#  ('peace', 'rival', 'another'),
#  ('rival', 'another', 'cool'),
#  ('another', 'cool', 'discovery'),
#  ('cool', 'discovery', 'traif'),
#  ('discovery', 'traif', 'bike'),
#  ('traif', 'bike', 'geshefton'),
#  ('bike', 'geshefton', 'williamburg'),
#  ('geshefton', 'williamburg', 'side'),
#  ('williamburg', 'side', 'bridge'),
#  ('side', 'bridge', 'address'),
#  ('bridge', 'address', 'south'),
#  ('address', 'south', 'street'),
#  ('south', 'street', 'bedford'),
#  ('street', 'bedford', 'berry'),
#  ('bedford', 'berry', 'street'),
#  ('berry', 'street', 'please'),
#  ('street', 'please', 'note'),
#  ('please', 'note', 'open'),
#  ('note', 'open', 'accept'),
#  ('open', 'accept', 'cash'),
#  ('accept', 'cash', 'form'),
#  ('cash', 'form', 'payment'),
#  ('form', 'payment', 'happen'),
#  ('payment', 'happen', 'get'),
#  ('happen', 'get', 'flat'),
#  ('get', 'flat', 'pump'),
#  ('flat', 'pump', 'use'),
#  ('pump', 'use', 'also'),
#  ('use', 'also', 'outside'),
#  ('also', 'outside', 'vending'),
#  ('outside', 'vending', 'machine'),
#  ('vending', 'machine', 'buy'),
#  ('machine', 'buy', 'pump'),
#  ('buy', 'pump', 'tire'),
#  ('pump', 'tire', 'repair'),
#  ('tire', 'repair', 'kit'),
#  ('repair', 'kit', 'small'),
#  ('kit', 'small', 'etc'),
#  ('small', 'etc', 'although'),
#  ('etc', 'although', 'longer'),
#  ('although', 'longer', 'rent'),
#  ('longer', 'rent', 'bike'),
#  ('rent', 'bike', 'catch'),
#  ('bike', 'catch', 'flat'),
#  ('catch', 'flat', 'place'),
#  ('flat', 'place', 'go'),
#  ('place', 'go', 'repair'),
#  ('go', 'repair', 'direction'),
#  ('repair', 'direction', 'traif'),
#  ('direction', 'traif', 'bike'),
#  ('traif', 'bike', 'gesheft'),
#  ('bike', 'gesheft', 'located'),
#  ('gesheft', 'located', 'south'),
#  ('located', 'south', 'street'),
#  ('south', 'street', 'click'),
#  ('street', 'click', 'link'),
#  ('click', 'link', 'public'),
#  ('link', 'public', 'employee'),
#  ('public', 'employee', 'father'),
#  ('employee', 'father', 'top'),
#  ('father', 'top', 'busy'),
#  ('top', 'busy', 'enjoying'),
#  ('busy', 'enjoying', 'mother'),
#  ('enjoying', 'mother', 'realized'),
#  ('mother', 'realized', 'another'),
#  ('realized', 'another', 'presence'),
#  ('another', 'presence', 'kind'),
#  ('presence', 'kind', 'dad'),
#  ('kind', 'dad', 'altho'),
#  ('dad', 'altho', 'pure'),
#  ('altho', 'pure', 'energy'),
#  ('pure', 'energy', 'physical'),
#  ('energy', 'physical', 'recognized'),
#  ('physical', 'recognized', 'energy'),
#  ('recognized', 'energy', 'signature'),
#  ('energy', 'signature', 'right'),
#  ('signature', 'right', 'franklyn'),
#  ('right', 'franklyn', 'pleiadian'),
#  ('franklyn', 'pleiadian', 'guide'),
#  ('pleiadian', 'guide', 'turn'),
#  ('guide', 'turn', 'equally'),
#  ...]

# %%
test = tokens[:10000]

# %%
type(test)
# Out:
# list

# %% [markdown]
# ### Model Training for 3 N-Grams

# %%
# Preprocess the tokenized text for 3-grams language modelling

n = 3

train_data, padded_sents = padded_everygram_pipeline(n, test)

# %%
model = MLE(order=3)

# %%
len(model.vocab)
# Out:
# 0

# %%
model.fit(train_data, padded_sents)
print(model.vocab)
# Out:
# <Vocabulary with cutoff=1 unk_label='<UNK>' and 34 items>

# %%
len(model.vocab)
# Out:
# 34

# %%
model.vocab.lookup(test[0])
# Out:
# '<UNK>'

# %%
model.vocab.lookup('heart is never random lah .'.split())
# Out:
# ('<UNK>', '<UNK>', '<UNK>', '<UNK>', '<UNK>', '<UNK>')

# %%
print(model.counts)
# Out:
# <NgramCounter with 3 ngram orders and 264657 ngrams>

# %%
model.counts['heart']
# Out:
# 0

# %%
model.score('away')
# Out:
# 0.0

# %% [markdown]
# ### Generation using N-gram Language Model

# %%
print(model.generate(20, random_seed=7))
# Out:
# ['<s>', '<s>', 'p', 'a', 'r', 'd', '</s>', '</s>', '</s>', '</s>', '</s>', '</s>', '</s>', '</s>', '</s>', '</s>', '</s>', '</s>', '</s>', '</s>']

# %%
# Function to extract words from model results

from nltk.tokenize.treebank import TreebankWordDetokenizer

detokenize = TreebankWordDetokenizer().detokenize

def generate_sent(model, num_words, random_seed=42):
    """
    :param model: An ngram language model from `nltk.lm.model`.
    :param num_words: Max no. of words to generate.
    :param random_seed: Seed value for random.
    """
    content = []
    for token in model.generate(num_words, random_seed=random_seed):
        if token == '<s>':
            continue
        if token == '</s>':
            break
        content.append(token)
    return detokenize(content)

# %% [markdown]
# ### Generating 3 random results

# %%
generate_sent(model, 20, random_seed=7)
# Out:
# 'p a r d'

# %%
generate_sent(model, 20, random_seed=23)
# Out:
# 't u r a p h i l d'

# %%
generate_sent(model, 20, random_seed=45)
# Out:
# 'b e a'

# %% [markdown]
# ### Load the subset 10000 lines dataset

# %%
df = pd.read_csv("blogdata.csv")

# %%
df
# Out:
#                                                   words
# 0       We have given our hearts away, a sordid boon !”
# 1                               1. Start it on the side
# 2                             Sugar’s sweet, so is she,
# 3     So because the Asian community was so by need ...
# 4     Nicholas’ brain runs on and is excellent at pr...
# ...                                                 ...
# 9995  Perfect timing for Friday Fragments! I have a ...
# 9996  Herbert paid his debt to society by twiddling ...
# 9997                         20. A Warning From The Sun
# 9998  Sherry and John from Young House Love are team...
# 9999  BE CAREFUL NOT TO INCLUDE SPOILERS! (make sure...
#
# [10000 rows x 1 columns]

# %%
blog_corpus = list(df['words'].apply(word_tokenize))

# %%
blog_corpus;

# %%
n = 3
train_data, padded_sents = padded_everygram_pipeline(n, blog_corpus)

# %%
blog_model = MLE(n) # Lets train a 3-grams model, previously we set n=3
blog_model.fit(train_data, padded_sents)

# %% [markdown]
# ### Generating 3 random results

# %%
generate_sent(blog_model, num_words=20, random_seed=42)
# Out:
# 'money), Susheela Raman, Lila Downs, Nelson Mandela, Aziza Mustafa Zadeh, Margaret engages in an'

# %%
generate_sent(blog_model, num_words=10, random_seed=0)
# Out:
# 'the reverse of the internet . Or is it generally'

# %%
generate_sent(blog_model, num_words=50, random_seed=10)
# Out:
# 'incredible hostesses also asked us to new heights – and changing it to 215 countries around the corner . From the parking, the word “ home ” and filled with excitement!!!'

# %% [markdown]
# ***

# %% [markdown]
# #### Coded and submitted by Dennis Lam 2021
